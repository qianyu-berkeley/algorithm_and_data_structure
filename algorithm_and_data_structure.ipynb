# %% [markdown]
# # Algorithm and Data Structure with Python

# %% [markdown]
# ## Efficiency
#
# * Time efficiency and Space efficiency are both important
#
# ### Big O Notation:
#
# * $O(n)$ notation: n represents the length of input to your funciton
# * We can also use bit O notation for space efficency
# * focus on worst case (or need to indicate whether we are talking about worse case or average during the interview)
# * lower order term does not matter can be igored
# * Constant factors (coefficient does not matter) => `Drop`
#     * Not a huge difference (could get a computer that's twice as fast)
#     * Our elementary steps may not take the same amount of time
#         * $2 \times n \times 2$ may not really take twice as long as $n \times 2$
#     * Deeper mathematical reason:
#         * There is a theorem that says you can always decrease the coefficient if you increase the lower order terms
#         * So the constant actually isn't meaningful
# * Our function f is big $O$ of $g$, $ƒ \in O(g)$ => `Drop nondominant`
#     * if there is a constant c and some integer n0, such that $f(n) < c g(n)$ for all $n > n_0$
#     * $g$ becomes an upper bound on f (up to a constant)
#     * This may not be true for small n, but it eventually becomes true
#     * You can take this definition and show mathematically that lower order terms and constants don't matter
#     * $O(2n^2 + n)$ is the same as $O(n^2)$
#     * Most algorithms we work with will fall into one of a few growth-rate classes
#
# Note: $\Omega$ is the symbol best case, $\theta$ is symbol average case, $O$ is the symbol worst case
#
# * Reference:
#   * [Big O Cheatsheet](https://www.bigocheatsheet.com/)
#   * [Python Time Complexity](https://wiki.python.org/moin/TimeComplexity)
#
# ## Common Growth Functions:
#
# **Good/Fast**
# * $O(1)$ constant (same as $O(0 \cap +1)$
#     * Get item in a list
#     * Find a value in hash table
# * $O(\log (n))$
#     * Divide and conque
#     * find an item in a sorted list (binary search)
# * $O(n)$
#     * proportional
#     * add big integers, digit by digit
#     * add two vectors, multiple scalar
#     * inner products of vectors
# * $O(N \dot \log (N))$
#     * Fast Fourier Transform
#     * Find longest increasing subsequence in a sequence
#
# **Slow/bad**
# * $O(n^2)$
#     * Nested loops or loop within a loop
#     * multiple big integers, bit by bit
#     * write all pairs in a set
# * $O( N^a), a > 2$
#     * computer least square regression
#     * inverting NxN matrix
#     * Nesting a quadratic-time algorithm inside another non-constant-time algorithm
# * $P = Np$: Polynomial
#     * Computer scientists have a special term for problems that can be solved in polynomial time: P.
#         * This is the P in the famous conjecture P = NP.
#         * P represents a theoretical standard for easily solvable problems.
# * Exponential $O(2^n)$
#     * will outgrow any polynomial

# %% [markdown]
# # Collection
#
# ## List (Multiple implementation)
#
# ### Array
#
# * Compact in memory
# * Each element has an index (starts at 0)
# * Fast to access items thanks to index with $O(1)$
# * Insertion and deletion for array is linear time $O(n)$ because we need to shift elements over
#
# ### Referential Array
#
# * Each reference points to an item in a sequence, but the item can be stored anywhere in memory.
# * The item can also have any size.
# * With this combination, we can still find items in the array in constant time, though that constant time is slower.
# * This is the trick used by Python's list and tuple classes.
# * __Python lists are implemented as referential arrays__.
#
# ### Python List
#
# * Behind the scenes a Python list is built as an referntial array with optimization
# * Inserting into a Python list is actually $O(n)$, while operations that search for an element at a particular spot are $O(1)$
# * Python is a "higher level" programming language, so you can accomplish a task with little code. However, there's a lot of code built into the infrastructure in this way that causes your code to actually run much more slowly than you'd think.
# * Python list and tuple efficiency
#   * `len(data)`: $O(1)$
#   * `data[j]`: $O(1)$
#   * `data.count(value)`: $O(n)$
#   * `data.index(value)`: $O(k+1)$
#   * `value in data`: $O(k+1)$
#   * `data1 == data2`: $O(k+1)$ (similarly !=, <, <=, >, >=)
#   * `data[j:k]`: $O(k − j+1)$
#   * `data1 + data2`: $O(n1 +n2)$
#   * `c*data`: $O(cn)$

# %% [markdown]
# ## Linked List
#
# * Linked list does not have index associated with element but it has reference/pointer to the next/previous element
# * Insertion and removing and item in the beginning: $O(1)$
# * Insertion and removing an item in the middel: $O(n)$
# * To access or look up an element: $O(n)$
# * Better than list:
#     * prepend $O(1)$
#     * pop first $O(1)$
# * Worse than list:
#     * pop $O(n)$
#     * lookup by index $O(n)$
# * More memory overhead

# %%
# Linked List
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None


class LinkedList:
    def __init__(self, value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1

    def print_list(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next
        
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.head = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node
            
        self.length +=1
        return True
        
    def pop(self):
        if self.length == 0:
            return None
        
        temp = self.head
        pre = self.head
        while temp.next is not None:
            pre = temp
            temp = temp.next
        self.tail = pre
        self.tail.next = None
        self.length -= 1
        
        if self.length == 0:
            self.head = None
            self.tail = None
        return temp
        
    def prepend(self, value):
        new_node = Node(value)
        if self.length == 0:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head = new_node
        self.length += 1
        return True
        
    def pop_first(self):
        if self.length == 0:
            return None
        
        first = self.head
        self.head = self.head.next
        first.next = None
        self.length -= 1
        
        if self.length == 0:
            self.tail = None
        return first
    
    def get(self, index):
        if index >= self.length or index < 0:
            return None
        else:
            temp = self.head
            for _ in range(index):
                temp = temp.next
            return temp
    
    def set_value(self, index, value):
        temp = self.get(index)
        if temp:
            temp.value = value
            return True
        return False
    
    def insert(self, index, value):
        if index >= self.length or index < 0:
            return False 
        if index == 0:
            return self.prepend(value)
        if index == self.length:
            return self.append(value)
        
        new_node = Node(value)
        temp = self.get(index-1)
        new_node.next = temp.next
        temp.next = new_node
        self.length += 1
        return True
        
    def remove(self, index):
        if index >= self.length or index < 0 or self.length == 0:
            return None
        if index == 1:
            return self.pop_first()
        if index == self.length:
            return self.pop()
        
        prev = self.get(index-1)
        temp = prev.next
        prev.next = temp.next
        temp.next = None
        self.length -= 1
        return temp
    
    def reverse(self):
        # swith head and tail
        temp = self.head
        self.head = self.tail
        self.tail = temp
        after = temp.next
        before = None
        for _ in range(self.length):
            after = temp.next
            temp.next = before
            before = temp
            temp = after
        
            

# setting up a LinkedList (1 -> 2 -> 3)
print("test create ll")
ll = LinkedList(1)
ll.print_list()
print("-------------")
print("test append")
ll.append(2)
ll.print_list()
print("-------------")
print("test pop")
print(ll.pop())
ll.print_list()
print(ll.pop())
ll.print_list()
print(ll.pop())
print("-------------")
print("test prepend")
ll = LinkedList(2)
ll.append(3)
ll.prepend(1)
ll.print_list()
print("-------------")
print("test pop first")
ll = LinkedList(2)
ll.append(1)
print(ll.pop_first())
print(ll.pop_first())
print(ll.pop_first())
print("-------------")
print("test get")
ll = LinkedList(1)
ll.append(2)
ll.append(3)
ll.get(2)
print("-------------")
print("test remove")
ll = LinkedList(1)
ll.append(3)
ll.append(2)
ll.append(1)
print(ll.remove(2))
ll.print_list()
print("-------------")
print("test reverse")
ll = LinkedList(1)
ll.append(2)
ll.append(3)
ll.append(4)
ll.reverse()
ll.print_list()
# Out:
# test create ll
# 1
# -------------
# test append
# 1
# 2
# -------------
# test pop
# <__main__.Node object at 0x7fb7261a15e0>
# 1
# <__main__.Node object at 0x7fb7261a1ca0>
# None
# -------------
# test prepend
# 1
# 2
# 3
# -------------
# test pop first
# <__main__.Node object at 0x7fb7261a2280>
# <__main__.Node object at 0x7fb7261a1c10>
# None
# -------------
# test get
# -------------
# test remove
# <__main__.Node object at 0x7fb724cc16a0>
# 1
# 3
# 1
# -------------
# test reverse
# 4
# 3
# 2
# 1

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self, value):
        new_node = Node(value)
        self.head = new_node
        self.tail = new_node
        self.length = 1
    
    def print_list(self):
        temp = self.head
        while temp is not None:
            print(temp.value)
            temp = temp.next
    
    def append(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.prev = self.tail
            self.tail.next = new_node
            self.tail = new_node
        self.length += 1
        return True
    
    def pop(self):
        # 0 item
        if self.head is None:
            return None
        temp = self.tail
        # 1 item
        if self.length == 1:
            self.head = None
            self.tail = None
        # > 1 items
        else:
            self.tail = self.tail.prev
            self.tail.next = None
            temp.prev = None
        self.length -= 1
        return temp
    
    def prepend(self, value):
        new_node = Node(value)
        if self.head is None:
            self.head = new_node,
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node
        self.length += 1
        return True
    
    def popfirst(self):
        if self.head is None:
            return None
        temp = self.head
        if self.length == 1:
            self.head = None
            self.tail = None
        else:
            self.head = self.head.next
            self.head.prev = None
            temp.next = None
        self.length -= 1
        return temp
    
    def get(self, index):
        # can optimize based on the index since we can start from the end
        if index <0 or index >= self.length:
            return None
        temp = self.head
        if index < self.length/2:
            for _ in range(index):
                temp = temp.next
        else:
            temp = self.tail
            for _ in range(self.lenth-1, index, -1):
                temp = temp.prev
        return temp
    
    def set_value(self, index, value):
        temp = self.get(index)
        if temp:
            temp.value = value
            return True
        return False
    
    def insert(self, index, value):
        if index < 0 or index > self.length:
            return False
        new_node = Node(value)
        if index == 0:
            return self.prepand(value)
        if index == self.length:
            return self.append(value)
        before = self.get(index - 1)
        after = before.next
        new_node.prev = before
        new_node.next = after
        before.next = new_node
        after.prev = new_node
        self.length+=1
        return True

    def remove(self, index):
        if index < 0 or index > self.length:
            return None
        if index == 0:
            return self.popfirst()
        if index == self.length - 1
            return self.pop()
        
        before = self.get(index - 1)
        current = before.next
        after = before.next.next
        before.next = after
        after.prev = before
        current.next = None
        current.prev = None
        self.length-=1
        return current

# %% [markdown]
# ### Stack
#
# * LIFO (Last In First Out)
# * applications: browsing history, undo history, execution stack
# * use push and pop functions
# * Can be implemented using array or linked list
#     * If use list, we want to append at the end and pop to get $O(1)$
#     * If use linked list, to achieve $O(1)$ we push to the head
#
# #### Using Array
# * $O(1)$ amortized push/pop time
# * May be faster to push/pop a lot of elements, if they're right next to each other on disk
# * compact memory space
#
# #### Stack with Python List
# * S.push() => L.append()
# * S.pop() => L.pop()
# * S.top() => L[-1]
# * S.is_empty() => len(L) == 0
# * len(S) = len(L)
#
# #### Using linked list:
#   * Instead of append() to the end like list, we insert first and delete first which is faster for linked list

# %%
# implemnt stack using python list
class stack:

    def __init__(self):
        self._data = [[]]
    
    def push(self, e):
        self._data.append(e)
    
    def pop(self):
        if len(self._data) == 0:
            raise Exception("Stack is empty!!")
        return self._data.pop(-1)

# implement using linked list
class Element(object):
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList(object):
    def __init__(self, head=None):
        self.head = head

    def append(self, new_element):
        current = self.head
        if self.head:
            while current.next:
                current = current.next
            current.next = new_element
        else:
            self.head = new_element

    def insert_first(self, new_element):
        new_element.next = self.head
        self.head = new_element

    def delete_first(self):
        if self.head:
            deleted_element = self.head
            temp = deleted_element.next
            self.head = temp
            return deleted_element
        else:
            return None

class Stack(object):
    def __init__(self,top=None):
        self.ll = LinkedList(top)

    def push(self, new_element):
        self.ll.insert_first(new_element)

    def pop(self):
        return self.ll.delete_first()


# Test cases
# Set up some Elements
e1 = Element(1)
e2 = Element(2)
e3 = Element(3)
e4 = Element(4)

# Start setting up a Stack
stack = Stack(e1)

# Test stack functionality
stack.push(e2)
stack.push(e3)
# 3 -> 2 -> 1
print(f"Should get 3: {stack.pop().value}") 
print(f"Should get 2: {stack.pop().value}")
print(f"Should get 1: {stack.pop().value}")
print(f"Should get None: {stack.pop()}")
stack.push(e4)
# 4
print(f"Should get 4: {stack.pop().value}")
# Out:
# Should get 3: 3
# Should get 2: 2
# Should get 1: 1
# Should get None: None
# Should get 4: 4

# %%
# Build Stack as linked list
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class Stack:
    def __init__(self, value):
        new_node = Node(value)
        self.top = new_node
        self.height = 1
    
    def print_stack(self):
        temp = self.top
        while temp is not None:
            print(temp.value)
            temp = temp.next
    
    def push(self, value): # prepend in LL
        new_node = Node(value)
        if self.height == 0:
            self.top = new_node
        else:
            new_node.next = self.top
            self.top = new_node
        self.height+=1
    
    def pop(self): # popfirst in LL
        if self.height == 0:
            return None
        else:
            temp = self.top
            self.top = self.top.next
            temp.next = None
            self.height-=1
            return temp

# %% [markdown]
# ### Queue
#
# * FIFO
# * Operations:
#     * enqueue(e) : Add item to the back of a Q
#     * dequeue(e) : Remove the first item of Q and return it.
#     * first() : return the first item without removing it
#     * is_empty(): check if the Q is empty
# * application:
#     * network router
#     * Web service (page history)
# * Implement with pointer (begin, end) enable dequeue and enqueue to be $O(1)$ if fixed length
# * A good idea is to wrap back around to the beginning.
#     * We can compute indices using the % operator (mod n).
#     * For example, back = back + 1 % n
#     * We just have to watch out that we don't enqueue when back + 1 % n == start
# * If we use a dynamic array, we may have to copy everything into a larger array
#     * Enqueue and dequeue both have worst-case time $O(n)$ but amortized time $O(1)$
#     * This is the default behavior in many programming libraries
# * A linkedList based queue is simple to implement and core operations are $O(1)$
#
# #### Python build-in Deque
# * Designed to have fast appends and pops from both ends compare to python array
# * double ended queue can be enqueue from both left and right

# %%
from collections import deque
 
queue = deque(["Eric", "John", "Michael"])
queue.append("Terry")           # Terry arrives
queue.append("Graham")          # Graham arrives
print(f"Should get Eric: {queue.popleft()}")
print(f"Should get John: {queue.popleft()}")
print(f"Should get ['Michael', 'Terry', 'Graham']: {queue}")
# Out:
# Should get Eric: Eric
# Should get John: John
# Should get [Michael]: deque(['Michael', 'Terry', 'Graham'])

# %% [markdown]
# #### Implement queue using python list

# %%
class Queue:
    def __init__(self, head=None):
        self.storage = [head]

    def enqueue(self, new_element):
        self.storage.append(new_element)

    def peek(self):
        return self.storage[0]

    def dequeue(self):
        return self.storage.pop(0)

# Setup 
q = Queue(1)
q.enqueue(2)
q.enqueue(3)

# Test peek
print(f"should get 1: {q.peek()}")

# Test dequeue 
print(f"should get 1: {q.dequeue()}")

# Test enqueue
q.enqueue(4)
print(f"Should get 2: {q.dequeue()}")
print(f"Should get 3: {q.dequeue()}")
print(f"Should get 4: {q.dequeue()}")
q.enqueue(5)
print(f"Should get 5: {q.peek()}")
# Out:
# should get 1: 1
# should get 1: 1
# Should get 2: 2
# Should get 3: 3
# Should get 4: 4
# Should get 5: 5

# %% [markdown]
# #### Implement queue using linked list

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None
        
class Queue:
    def __init__(self, value):
        new_node = Node(value)
        self.first = new_node
        self.last = new_node
        self.length = 1
    
    def print_queue(self):
        temp = self.first
        while temp is not None:
            print(temp.value)
            temp = temp.next
            
    def enqueue(self, value): # append in LL
        new_node = Node(value)
        if self.first is None:
            self.first = new_node
            self.last = new_node
        else:
            self.last.next = new_node
            self.last = new_node
        self.length+=1
    
    def dequeue(self): # pop first
        if self.length == 0:
            return None
        
        temp = self.first
        if self.length == 1:
            self.first = None
            self.last = None
        else:
            self.first = self.first.next
            temp.next = None
        self.length-=1 
        return temp
        
        
# Setup 
q = Queue(1)
q.enqueue(2)
q.enqueue(3)
q.print_queue()
print("-------")
q.dequeue()
q.print_queue()
print("-------")
q.dequeue()
q.print_queue()
print("-------")
q.dequeue()
q.print_queue()
# Out:
# 1
# 2
# 3
# -------
# 2
# 3
# -------
# 3
# -------

# %% [markdown]
# ## Tree (Focus on BTS)
#
# * Requirements
#   * Nodes must be connected
#   * Cannot be cyclical
# * Terminology
#   * tree:
#       * Full
#       * perfect
#       * complete
#   * Parent, child nodes (leaf)
#   * Level: How many connections to reach from root and +1
#   * height: num of edges between root and furthest leaf in the tree (root has the largest value)
#   * Depth: inverse of height where leaf has the largest value)
# * Binary search tree
#     * larger than root => right
#     * less than root => left

# %%
# Binary Tree
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        # something points ot the top of the tree
        self.root = None 

    # without using recursion
    def insert(self, value)
        new_node = Node(value)
        
        if self.root is None:
            self.root = value
            return True
        
        temp = self.root
        while True:
            if new_node.value == temp.value:
                return False
            if new_node.value <= temp.value:
                if temp.left is None:
                    temp.left = new_node
                    return True
                temp = temp.left
            else:
                if temp.right is None:
                    temp.right = new_node
                    return True
                temp = temp.right
    
    def contains(self, value):
        if self.root is None:
            return False
        
        temp = self.root
        while temp is not None:
            if value < temp.value:
                temp = temp.left
            elif value > temp.value:
                temp = temp.right
            else:
                return True
        return False

# %% [markdown]
# ### Binary Search (BST)
#
# * $O(\log_{2}(n))$ (To be exact, it is $O(\log_{2} (n) + 1)$)
#   * n is the length of the list
#   * We divided by 2 for binary search
#   * If it is odd number, we compare the center, if it is even number, we start with lower half
#   * To get the worst case, we try to find an item that is largest
#   * The worst case is $O(n)$ if the tree is not balanced
#
# * Compare to linked list
#     * LL is $O(n)$ for lookup() and remove(), BTS is faster
#     * LL is fast in insert(), since we do not sort, we just append. BST require sort based on node value
#
#
# ### Python search with list
# * `index()` building function return the first index with an instance of the value

# %%
# Binary Search
# Element is sorted in increasing order
def binary_search(input_list, value):
    size = len(input_list)
    low = 0
    high = size - 1
    while low <= high:
        mid = int((low + high)/2)
        if input_list[mid] == value:
            return mid
        elif input_list[mid] > value:
            high = mid - 1
        else:
            low = mid + 1
    return -1

test_list = [1, 2, 3, 4, 5, 6, 7, 8]   

print(f"Should return 4: {binary_search(test_list, 5)}")
print(f"Should return -1: {binary_search(test_list, 10)}")
print(f"Should return 0: {binary_search(test_list, 1)}")
print(f"Should return -1: {binary_search([], 3)}")
# Out:
# Should return 4: 4
# Should return -1: -1
# Should return 0: 0
# Should return -1: -1

# %% [markdown]
# ### 3 Templates for BS

# %%
# Template 1 Standard
# Most basic and elementary form of Binary Search
# Search Condition can be determined without comparing to the element's neighbors 
#(or use specific elements around it)
# No post-processing required because at each step, you are checking to see 
# if the element has been found. If you reach the end, then you know the element is not found
def binarySearch(nums, target):
    """
    :type nums: List[int]
    :type target: int
    :rtype: int
    """
    if len(nums) == 0:
        return -1

    left, right = 0, len(nums) - 1
    while left <= right:
        mid = (left + right) // 2
        if nums[mid] == target:
            return mid
        elif nums[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    # End Condition: left > right
    return -1

# %% [markdown]
# ### Resurive BST

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        # something points ot the top of the tree
        self.root = None 
    
    def __r_contains(self, current_node, value):
        if current_node == None:
            return False
        if value == current_node.value:
            return True
        if value < current_node.value:
            return self.__r_contains(current_node.left, value)
        if value > current_node.value:
            return self.__r_contains(current_node.right, value)
    
    def __r_insert(self, current_node, value):
        if current_node == None:
            return Node(value)
        if value < current_node.value:
            current_node.left = self.__r_insert(current_node.left, value)
        if value > current_node.value:
            current_node.right = self.__r_insert(current_node.right, value)
        return current_node
    
    def __delete_node(self, current_node, value):
        if current_node == None:
            return None
        if value < current_node.value:
            current_node.left = self__delete_node(current_node.left, value)
        elif value > current_node.value
            current_node.right = self__delete_node(current_node.right, value)
        else: #(4 situations)
            # if it is a leaf node
            if current.left == None and current_node.right == None:
                return None
            # has a right node not a left node
            elif current_node.left == None:
                current_node = current_node.right
            # has a left node not a right node
            elif current_node.right == None:
                current_node = current_node.left
            # has subtree, need to find min value in the subtree and replace the to be deleted node
            else:
                sub_tree_min = self.min_value(current_node.right)
                current_node.value = sub_tree_min
                current_node.right = self.__delete_node(current_node.right, sub_tree_min)
            
        return current_node
        
        
    def r_contains(self, value):
        return self.__r_contains(self.root, value)
    
    def r_insert(self, value):
        # take care of edge case of empty BST
        if self.root == None:
            self.root = Node(value)
        self.__r_insert(self.root, value)
    
    def delete_node(self, value):
        self.root = self.__delete_node(self.root, value)
    
    def min_value(self, current_node): #helper function for delete
        while current_node.left is not None:
            current_node = current_node.left
        return current_node.value

# %% [markdown]
# ### Tree Travesal
#
# * Visit every node in the tree
# * Put node in a list and return it
# * methods:
# * Traversal
#   * Breadth First Search(BFS) (level order)
#     * we visit the root.
#     * Then we visit each level 1 node.
#     * Then we visit each level 2 node.
#     * Etc. …
#     * use a queue and add children of a root (nodes at each level) to a queue
#
#     ```python
#     def breadth_first_traverse(T):
#         """Traverse a tree, breadth first,
#            and print all values"""
#
#         Q = Queue()
#         Q.enqueue(T)
#
#         while not Q.is_empty():
#             v = Q.dequeue()
#             print(v.value)
#             for child in v.get_children():
#                 Q.enqueue(child)
#     ```
#   * Depth first search (DFS) (3 type: pre-order, in-order, post-order)
#     * Visit the root node.
#     * Traverse the subtree rooted at each child of the root.
#
#     ```python
#     def Traverse(T):
#         """Traverse a tree and print all values"""
#
#         print(T.value)
#         for child in T.get_children():
#             Traverse(child)
#     ```

# %%
    def BFS(self):
        current_node = self.root
        queue = []
        results = []
        queue.append(current_node)
        
        while len(queue) > 0:
            current_node = queue.pop(0)
            results.append(current_node.value)
            if current_node.left is not None:
                queue.append(current_node.left)
            if current_node.right is not None:
                queue.append(current_node.right)
        return results
    
    def dfs_pre_order(self):
        result = []
        def traverse(current_node):
            # append node first, then left, the right
            results.append(current_node.value)
            if current_node.left is not None:
                traverse(current_node.left)
            if current_node.right is not None:
                traverse(current_node.right)
        traverse(self.root)
        return results
    
    def dfs_post_order(self):
        results = []
        
        def traverse(current_node):
            # left first, then right, then node
            if current_node.left is not None:
                traverse(current_node.left)
            if current_node.right is not None:
                traverse(current_node.right)
            results.append(current_node.value)
        traverse(self.root)
        return results
    
    def dfs_in_order(self):
        results = []
        
        def traverse(current_node):
            # left first, then node, then right
            if current_node.left is not None:
                traverse(current_node.left)
            results.append(current_node.value)
            if current_node.right is not None:
                traverse(current_node.right)
        traverse(self.root)
        return results

# %%
class BinaryTree(object):
    def __init__(self, root):
        self.root = Node(root)

    def search(self, find_val):
        return self.preorder_search(self.root, find_val)

    def print_tree(self):
        return self.preorder_print(self.root, "")[:-1]

    def preorder_search(self, start, find_val):
        if start:
            if start.value == find_val:
                return True
            else:
                return self.preorder_search(start.left, find_val) or self.preorder_search(start.right, find_val)
        return False

    def preorder_print(self, start, traversal):
        if start:
            traversal += (str(start.value) + "-")
            traversal = self.preorder_print(start.left, traversal)
            traversal = self.preorder_print(start.right, traversal)
        return traversal


class BST(object):
    def __init__(self, root):
        self.root = Node(root)

    def insert(self, new_val):
        self.insert_helper(self.root, new_val)

    def insert_helper(self, current, new_val):
        if current.value < new_val:
            if current.right:
                self.insert_helper(current.right, new_val)
            else:
                current.right = Node(new_val)
        else:
            if current.left:
                self.insert_helper(current.left, new_val)
            else:
                current.left = Node(new_val)

    def search(self, find_val):
        return self.search_helper(self.root, find_val)

    def search_helper(self, current, find_val):
        if current:
            if current.value == find_val:
                return True
            elif current.value < find_val:
                return self.search_helper(current.right, find_val)
            else:
                return self.search_helper(current.left, find_val)
        return False

# %% [markdown]
# ## Hash Table
#
# * One of the most important data structure that give constant time look-up
# * Hash function is the map key to an integer in the range [0, N-1] (N is the capacity of bucket array for a hash table)
#   * oner-way look-up deterministic
#   * $f: h(k)$
#   * If 2 or more keys wit the same hash value, we have a collision
#
# * Dealing with Collision
#     * **Seperate Chaining** (store in the samme location as a chain, or linkedlist)
#     * Linear probing (open addressing)
#
# * Load Factor = Number of Entries / Number of Buckets
#   * The purpose of a load factor is to give us a sense of how "full" a hash table is
#   * The closer our load factor is to 1 (meaning the number of values equals the number of buckets), the better it would be for us to rehash and add more buckets. Any table with a load value greater than 1 is guaranteed to have collisions.
# * Big O
#     * set_item, get_item is $O(1)$
#     * Even with collision, it is close to $O(1)$ since most time, hash key is well distributed to avoid collision

# %%
class HashTable:
    def __init__(self, size=7): # use prime number as default increase randomness of hash key
        self.data_map = [None]*size

    def _hash(self, key):
        my_hash = 0
        for letter in key:
            #ord() get ascii number, % by 7 gets key from 0 - 6
            my_hash = (my_hash + ord(letter)*23)%len(self.data_map) 
        return my_hash

    def print_table(self):
        for i, val in enumerate(self.data_map):
            print(i, ": ", val)

    def set_item(self, key, value):
        index = self._hash(key)
        if self.data_map[index] == None: 
            self.data_map[index] = []
        self.data_map[index].append([key, value])
    
    def get_item(self, key):
        index = self._hash(key)
        if self.data_map[index] is not None:
            for i in range(len(self.data_map[index])):
                if self.data_map[index][i][0] == key:
                    return self.data_map[index][i][1]
        return None
            
    def keys(self):
        all_keys = []
        for i in range(len(self.data_map)):
            if self.data_map[i] is not None:
                for j in range(len(self.data_map[i])):
                    all_keys.append(self.data_map[i][j][0])
        return all_keys
        

# Setup
hash_table = HashTable()

# Test calculate_hash_value
print(hash_table._hash('UDACITY'))

# Test lookup edge case
# Should be -1
print(hash_table.get_item('UDACITY'))

# Test store
hash_table.set_item('UDACITY', 200)
# Should be 8568
print(hash_table.get_item('UDACITY'))
hash_table.set_item('UDACIOUS', 400)
print(hash_table.get_item('UDACIOUS'))

# test keys
print(hash_table.keys())
# Out:
# 5
# None
# 200
# 400
# ['UDACITY', 'UDACIOUS']

# %% [markdown]
# ### Sets
#
# Sets are similar to dictionaries except that instead of having key/value pairs they only have the keys but not the values.
#
# Like dictionaries, they are implemented using a **hash table** (which is why we are covering them here).
#
# Sets can only contain unique elements (meaning that duplicates are not allowed).
#
# They are useful for various operations such as finding the distinct elements in a collection and performing set operations such as union and intersection.
#
# They are defined by either using curly braces `{}` or the built-in `set()` function like this:
#
#
# ```python
# # Create a set using {}
# my_set = {1, 2, 3, 4, 5}
#
# # Create a set using set()
# my_set = set([1, 2, 3, 4, 5])
# ```
#
# Once a set is defined, you can perform various operations on it, such as adding or removing elements, finding the union, intersection, or difference of two sets, and checking if a given element is a member of a set.
#
# Here are some examples of common set operations in Python:
#
#
# ```python
# # Add an element to a set
# # If the number 6 is already in the set it will not be added again.
# my_set.add(6)
#
# # Update is used to add multiple elements to the set at once.
# # It takes an iterable object (e.g., list, tuple, set) as an
# # argument and adds all its elements to the set.
# # If any of the elements already exist in the set,
# # they are not added again.
# my_set.update([3, 4, 5, 6])
#
# # Removing an element from a set
# my_set.remove(3)
#
# # Union of two sets
# other_set = {3, 4, 5, 6}
# union_set = my_set.union(other_set)
#
# # Intersection of two sets
# intersection_set = my_set.intersection(other_set)
#
# # Difference between two sets
# difference_set = my_set.difference(other_set)
#
# # Checking if an element is in a set
# if "hello" in my_set:
#     print("Found hello in my_set")
# ```

# %% [markdown]
# ## Graph
#
# * Node or vertex connects edgies
# * edge can be weighted or not weighted, edge can be directional and bidirectional
#     * Tree and linkedlist are form of graph with limitation of directional
# * **Disconnected**: Disconnected graphs are very similar whether the graph's directed or undirected—there is some vertex or group of vertices that have no connection with the rest of the graph.
# * **Weakly Connected**: A directed graph is weakly connected when only replacing all of the directed edges with undirected edges can cause it to be connected. Imagine that your graph has several vertices with one outbound edge, meaning an edge that points from it to some other vertex in the graph. There's no way to reach all of those vertices from any other vertex in the graph, but if those edges were changed to be undirected all vertices would be easily accessible.
# * **Connected**: Here we only use "connected graph" to refer to undirected graphs. In a connected graph, there is some path between one vertex and every other vertex.
# * **Strongly Connected**: Strongly connected directed graphs must have a path from every node and every other node. So, there must be a path from A to B AND B to A.
#
# ### Graph Representation
#
# * Adjacency matrix
#     * represent vertex and vertex it has edge with using a matrix
#     * if not weighted 0 means not connected, 1 means connected, if weighted, we will store weights to the matrix
#     * if the graph is bidirectional, the adjacency matrix will be mirrored at diagno line
# * Adjacency list
#     * represent graph using a dictionary
#     * e.g.
#     ```python
#     {
#         'A':['B', 'E'],
#         'B':['A', 'C'],
#         'C':['B', 'D'],
#         'D':['C', 'E'],
#         'E':['A', 'D'],
#     }
#     ```
#     * key is the vertex, value using a list to store connected vertexes
#
#  * Complexity
#      * Space complexity $O(|V|^2)$ for adjacency matrix and $O(|V|+|E|)$ for adjacency list
#      * Adding a vertex: $O(|V|^2)$ for adjacency matrix and $O(1)$ for adjacency list
#      * Adding an edge: $O(1)$ for adjacency matrix and $O(1)$ for adjacency list
#      * remove an edge: $O(1)$ for adjacency matrix and $O(|E|)$ for adjacency list
#      * remove a vertex: $O(|V|^2)$ for adjacency matrix and $O(|V|+|E|)$ for adjacency list

# %%
class Graph:
    def __init__(self):
        self.adj_list = {}
    
    def print_graph(self):
        for vertex in self.adj_list:
            print(vertex, ':', self.adj_list[vertex])
            
    def add_vertex(self, vertex):
        if vertex not in self.adj_list.key():
            self.adj_list[vertex] = []
            return True
        return False
    
    def add_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            self.adj_list[v1].append(v2)
            self.adj_list[v2].append(v1)
            return True
        return False
    
    def remove_edge(self, v1, v2):
        if v1 in self.adj_list.keys() and v2 in self.adj_list.keys():
            try: # to catch an exception where v1, v2 exist but are not connected
                self.adj_list[v1].remove(v2)
                self.adj_list[v2].remove(v1)
            except ValueError:
                pass
            return True
        return False
    
    def remove_vertex(self, vertex):
        if vertex in self.adj_list.keys():
            for ohter_vertex in self.adj_list[vertex]:
                self.adj_list['other_vertex'].remove(vertex)
            del self.adj_list[vertex]
            return True
        return False

# %% [markdown]
# ## Recursion
#
# * A function call itself unit it does not
# * 3 components
#   * Call itself
#   * A base case (to allow it to stop)
#       * Need to have condition that can be true
#       * have return statement
#   * A condition to update
# * Design
#     * Test for base case. All recursive call will eventually reach a base case
#     * Need to avoid infinite recursion
#     * Recur: if not, we perform one or more recursive call
#     * A successful recursive design sometimes requires that we redefine the original problem to facilitate similar-looking subproblems. Often, this involved reparameterizing the signature of the function
#     * When computer memory is at a premium, it is useful in some cases to be able to derive nonrecursive algorithms from recursive ones.
# * A recursion is a tail recursion if any recursive call that is made from one context is the very last operation in that context, with the return value of the recursive call (if any) immediately returned by the enclosing recursion. By necessity, a tail recursion must be a linear recursion
#   * example: factorial is not since __return n * factorial(n-1)__
#   * example: binary search is tail recursion
# * Classic Recurive problems:
#   * Factorial
#   * Fabinocci series
#     * It can be very inefficient with recursion since it series grows with $O(2^n)$)
#     * Use hash table to store values will make it much faster with $O(n)$
#   * Binary search
#   * Explore Sub-Directories

# %% [markdown]
# ### Factorial

# %%
# Factorial
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

# 1x2x3
print(f"Should get 6: {factorial(3)}")
# 1x2x3x4
print(f"Should get 24: {factorial(4)}")
# 1x2x3x4x5
print(f"Should get 120: {factorial(5)}")
# Out:
# Should get 6: 6
# Should get 24: 24
# Should get 120: 120

# %% [markdown]
# ### Fabonacci Sequence

# %%
from time import time

# Fibonacci with recursion 
def fib_recursion(n):
    if n==0 or n==1: 
        return n
    else:
        return fib_recursion(n-1) + fib_recursion(n-2)

def fib_fast_recursion(n):
    if n<=1:
        return (n, 0)
    else:
        (a, b) = fib_fast_recursion(n-1)
        return (a+b, a)
    
# Fibonacci without recursion
def fib_no_recursion(n): 
    if n==0 or n==1: 
        return n

    first = 0
    second = 1
    next = first + second
    for i in range(2, n): 
        first = second
        second = next
        next = first + second
    return next


def fib_fast_no_recursion(n):
    fab = [0]*(n+1)
    fab[0] = 1
    fab[1] = 1
    fab[2] = 1
    for i in range(3, n+1):
        fab[i] = fab[i-1] + fab[i-2]
    return fab[n]


# %time print(f"With recursion: {fib_recursion(35)}")
print("----------")
# %time print(f"With fast recursion: {fib_fast_recursion(35)}")
print("----------")
# %time print(f"No recursion: {fib_no_recursion(35)}")
print("----------")
# %time print(f"Fast no recursion: {fib_fast_no_recursion(35)}")
# Out:
# With recursion: 9227465
# CPU times: user 2.89 s, sys: 18.3 ms, total: 2.91 s
# Wall time: 2.96 s
# ----------
# With fast recursion: (9227465, 5702887)
# CPU times: user 28 µs, sys: 3 µs, total: 31 µs
# Wall time: 32.9 µs
# ----------
# No recursion: 9227465
# CPU times: user 19 µs, sys: 3 µs, total: 22 µs
# Wall time: 24.1 µs
# ----------
# Fast no recursion: 9227465
# CPU times: user 24 µs, sys: 3 µs, total: 27 µs
# Wall time: 27.9 µs

# %% [markdown]
# ### Disk space of sub folder

# %%
# Disk space of sub folders

import os
def disk_usage(path):
    total = os.path.getsize(path)
    if os.path.isdir(path):
        for filename in os.listdir(path):
            childpath = os.path.join(path, filename)
            total += disk_usage(childpath)
            
    print(f'{total:<7} {path}')
    return total

disk_usage('./')
# Out:
# 6148    ./.DS_Store
# 6281679 ./algorithms-in-python.pdf
# 16047   ./Python/algorithm_and_data_structure/data_structure_notebook.ipynb
# 56      ./Python/algorithm_and_data_structure/Assignment2_SampleIO/scramble_example/input.txt
# 76      ./Python/algorithm_and_data_structure/Assignment2_SampleIO/scramble_example/output.txt
# 260     ./Python/algorithm_and_data_structure/Assignment2_SampleIO/scramble_example
# 23      ./Python/algorithm_and_data_structure/Assignment2_SampleIO/strategy_example/input.txt
# 38      ./Python/algorithm_and_data_structure/Assignment2_SampleIO/strategy_example/output.txt
# 189     ./Python/algorithm_and_data_structure/Assignment2_SampleIO/strategy_example
# 577     ./Python/algorithm_and_data_structure/Assignment2_SampleIO
# 264814664 ./Python/algorithm_and_data_structure/return_train_2018Q4.csv
# 175018588 ./Python/algorithm_and_data_structure/return_train_2018Q1.csv
# 0       ./Python/algorithm_and_data_structure/test_strings.txt
# 28834   ./Python/algorithm_and_data_structure/algorithm.ipynb
# 72      ./Python/algorithm_and_data_structure/.ipynb_checkpoints/python_receipts-checkpoint.ipynb
# 3986    ./Python/algorithm_and_data_structure/.ipynb_checkpoints/data_structure_notebook-checkpoint.ipynb
# 27896   ./Python/algorithm_and_data_structure/.ipynb_checkpoints/algorithm-checkpoint.ipynb
# 32114   ./Python/algorithm_and_data_structure/.ipynb_checkpoints
# 6023    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_6/Assignment_6.ipynb
# 106243  ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_6/Assignment_6.pdf
# 112394  ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_6
# 3983    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_3.rtf
# 1815    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_5/Assignment_5.rtf
# 11      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_5/graph_example_files/input.txt
# 1297    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_5/graph_example_files/adj.txt
# 9       ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_5/graph_example_files/output.txt
# 1477    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_5/graph_example_files
# 3420    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_5
# 56      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/scramble_example_files/input.txt
# 76      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/scramble_example_files/output.txt
# 260     ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/scramble_example_files
# 23      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/winning_example_files/input.txt
# 38      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/winning_example_files/output.txt
# 189     ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/winning_example_files
# 41334   ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2/Assignment_2.pdf
# 41943   ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_2
# 87      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_4/postfix_example_files/input.txt
# 16      ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_4/postfix_example_files/output.txt
# 231     ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_4/postfix_example_files
# 2208    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_4/Assignment_4.rtf
# 2567    ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10/Assignment_4
# 164531  ./Python/algorithm_and_data_structure/1B_assignments_2016_11_10
# 41334   ./Python/algorithm_and_data_structure/Assignment.pdf
# 673022  ./Python/algorithm_and_data_structure/austen-sense.txt
# 139174  ./Python/algorithm_and_data_structure/python_receipts.ipynb
# 440929301 ./Python/algorithm_and_data_structure
# 6148    ./Python/.DS_Store
# 77103   ./Python/Python Bridge/Python_syllabus_proofed_v3+(1).pdf
# 7808820 ./Python/Python Bridge/Introducing_Python-Bill_Lubanovic/python_Introducing.pdf
# 3701395 ./Python/Python Bridge/Introducing_Python-Bill_Lubanovic/1449359361_Introducing.epub
# 11510343 ./Python/Python Bridge/Introducing_Python-Bill_Lubanovic
# 121763  ./Python/Python Bridge/FundamentalsofPythonOverview.pdf
# 280     ./Python/Python Bridge/branch_demo/namegame.py
# 41      ./Python/Python Bridge/branch_demo/.git/ORIG_HEAD
# 137     ./Python/Python Bridge/branch_demo/.git/config
# 142     ./Python/Python Bridge/branch_demo/.git/objects/d9/49433fec09d931089bf80ed39cc5271800e5d2
# 238     ./Python/Python Bridge/branch_demo/.git/objects/d9
# 140     ./Python/Python Bridge/branch_demo/.git/objects/d8/febad3a0a2a89cda8422d9a987230e076db89f
# 236     ./Python/Python Bridge/branch_demo/.git/objects/d8
# 54      ./Python/Python Bridge/branch_demo/.git/objects/cf/dd7736015b95e0e285e8483e0702bd31baa216
# 150     ./Python/Python Bridge/branch_demo/.git/objects/cf
# 173     ./Python/Python Bridge/branch_demo/.git/objects/27/4cb7c9fe2cb4266b50561acc71e3a5658eda3d
# 269     ./Python/Python Bridge/branch_demo/.git/objects/27
# 64      ./Python/Python Bridge/branch_demo/.git/objects/pack
# 172     ./Python/Python Bridge/branch_demo/.git/objects/8a/1a7112953b45e75fe1a5b7d9cc9a1e50de5b04
# 268     ./Python/Python Bridge/branch_demo/.git/objects/8a
# 54      ./Python/Python Bridge/branch_demo/.git/objects/75/03874756acf5c6c5a4b5c68cd6d58805b6f157
# 150     ./Python/Python Bridge/branch_demo/.git/objects/75
# 54      ./Python/Python Bridge/branch_demo/.git/objects/2f/87e68a01c503963c69a2a0ede8b0549c9300af
# 150     ./Python/Python Bridge/branch_demo/.git/objects/2f
# 64      ./Python/Python Bridge/branch_demo/.git/objects/info
# 95      ./Python/Python Bridge/branch_demo/.git/objects/c3/73b78778d865c3827c78da2db4d50ce3aa4900
# 191     ./Python/Python Bridge/branch_demo/.git/objects/c3
# 183     ./Python/Python Bridge/branch_demo/.git/objects/f6/fb577de6289fd2e3ed5484bd8c709eb4820b37
# 279     ./Python/Python Bridge/branch_demo/.git/objects/f6
# 2475    ./Python/Python Bridge/branch_demo/.git/objects
# 23      ./Python/Python Bridge/branch_demo/.git/HEAD
# 250     ./Python/Python Bridge/branch_demo/.git/info/exclude
# 346     ./Python/Python Bridge/branch_demo/.git/info
# 1020    ./Python/Python Bridge/branch_demo/.git/logs/HEAD
# 327     ./Python/Python Bridge/branch_demo/.git/logs/refs/heads/line_arg
# 503     ./Python/Python Bridge/branch_demo/.git/logs/refs/heads/master
# 958     ./Python/Python Bridge/branch_demo/.git/logs/refs/heads
# 1054    ./Python/Python Bridge/branch_demo/.git/logs/refs
# 2202    ./Python/Python Bridge/branch_demo/.git/logs
# 73      ./Python/Python Bridge/branch_demo/.git/description
# 896     ./Python/Python Bridge/branch_demo/.git/hooks/commit-msg.sample
# 4951    ./Python/Python Bridge/branch_demo/.git/hooks/pre-rebase.sample
# 1642    ./Python/Python Bridge/branch_demo/.git/hooks/pre-commit.sample
# 452     ./Python/Python Bridge/branch_demo/.git/hooks/applypatch-msg.sample
# 1239    ./Python/Python Bridge/branch_demo/.git/hooks/prepare-commit-msg.sample
# 189     ./Python/Python Bridge/branch_demo/.git/hooks/post-update.sample
# 398     ./Python/Python Bridge/branch_demo/.git/hooks/pre-applypatch.sample
# 1348    ./Python/Python Bridge/branch_demo/.git/hooks/pre-push.sample
# 3611    ./Python/Python Bridge/branch_demo/.git/hooks/update.sample
# 15078   ./Python/Python Bridge/branch_demo/.git/hooks
# 41      ./Python/Python Bridge/branch_demo/.git/refs/heads/line_arg
# 41      ./Python/Python Bridge/branch_demo/.git/refs/heads/master
# 210     ./Python/Python Bridge/branch_demo/.git/refs/heads
# 64      ./Python/Python Bridge/branch_demo/.git/refs/tags
# 402     ./Python/Python Bridge/branch_demo/.git/refs
# 112     ./Python/Python Bridge/branch_demo/.git/index
# 64      ./Python/Python Bridge/branch_demo/.git/branches
# 25      ./Python/Python Bridge/branch_demo/.git/COMMIT_EDITMSG
# 21426   ./Python/Python Bridge/branch_demo/.git
# 21834   ./Python/Python Bridge/branch_demo
# 18430   ./Python/Python Bridge/homework/Hyera_Moon_Week4Assignment4.ipynb
# 685     ./Python/Python Bridge/homework/Hyera_Moon_Week1Assignment/gas.py
# 668     ./Python/Python Bridge/homework/Hyera_Moon_Week1Assignment/piglatin.py
# 500     ./Python/Python Bridge/homework/Hyera_Moon_Week1Assignment/tip.py
# 637     ./Python/Python Bridge/homework/Hyera_Moon_Week1Assignment/averages.py
# 2682    ./Python/Python Bridge/homework/Hyera_Moon_Week1Assignment
# 108     ./Python/Python Bridge/homework/test_concepts_main.py
# 7471    ./Python/Python Bridge/homework/.ipynb_checkpoints/Hyera_Moon_Week3Assignment3-checkpoint.ipynb
# 18388   ./Python/Python Bridge/homework/.ipynb_checkpoints/Hyera_Moon_Week4Assignment4-checkpoint.ipynb
# 25987   ./Python/Python Bridge/homework/.ipynb_checkpoints
# 530     ./Python/Python Bridge/homework/report.pyc
# 7507    ./Python/Python Bridge/homework/Hyera_Moon_Week3Assignment3.ipynb
# 49      ./Python/Python Bridge/homework/find_lib_path.py
# 238     ./Python/Python Bridge/homework/report.py
# 55851   ./Python/Python Bridge/homework
# 671     ./Python/Python Bridge/github_common_commands.txt
# 28923   ./Python/Python Bridge/Course-Syllabus-master/week_11/11.2 - Functional Programming and Data Manipulation.ipynb
# 221613  ./Python/Python Bridge/Course-Syllabus-master/week_11/11.1 - The PyData Ecosystem.pptx
# 29573   ./Python/Python Bridge/Course-Syllabus-master/week_11/11.4 - NumPy Vectorization and Multi-Dimensional Arrays.ipynb
# 28407   ./Python/Python Bridge/Course-Syllabus-master/week_11/.ipynb_checkpoints/11.2 - Functional Programming and Data Manipulation-checkpoint.ipynb
# 31041   ./Python/Python Bridge/Course-Syllabus-master/week_11/.ipynb_checkpoints/11.3 -  NumPy Basics of Boolean Selection and Types-checkpoint.ipynb
# 28491   ./Python/Python Bridge/Course-Syllabus-master/week_11/.ipynb_checkpoints/11.4 - NumPy Vectorization and Multi-Dimensional Arrays-checkpoint.ipynb
# 28868   ./Python/Python Bridge/Course-Syllabus-master/week_11/.ipynb_checkpoints/11.5 - Query, Slicing, Combining Arrays-checkpoint.ipynb
# 116999  ./Python/Python Bridge/Course-Syllabus-master/week_11/.ipynb_checkpoints
# 33165   ./Python/Python Bridge/Course-Syllabus-master/week_11/11.3 -  NumPy Basics of Boolean Selection and Types.ipynb
# 32828   ./Python/Python Bridge/Course-Syllabus-master/week_11/11.5 - Query, Slicing, Combining Arrays.ipynb
# 463357  ./Python/Python Bridge/Course-Syllabus-master/week_11
# 49278   ./Python/Python Bridge/Course-Syllabus-master/week_10/10.3 Test-Driven Development.pptx
# 878     ./Python/Python Bridge/Course-Syllabus-master/week_10/stringutility/test_stringutility.py
# 463     ./Python/Python Bridge/Course-Syllabus-master/week_10/stringutility/stringutility.py
# 0       ./Python/Python Bridge/Course-Syllabus-master/week_10/stringutility/__init__.py
# 1501    ./Python/Python Bridge/Course-Syllabus-master/week_10/stringutility
# 13450   ./Python/Python Bridge/Course-Syllabus-master/week_10/10.4 Test-Driven Example.ipynb
# 13450   ./Python/Python Bridge/Course-Syllabus-master/week_10/.ipynb_checkpoints/10.4 Test-Driven Example-checkpoint.ipynb
# 13546   ./Python/Python Bridge/Course-Syllabus-master/week_10/.ipynb_checkpoints
# 77967   ./Python/Python Bridge/Course-Syllabus-master/week_10
# 4917    ./Python/Python Bridge/Course-Syllabus-master/week_2/2.9 - Ranges.ipynb
# 7532    ./Python/Python Bridge/Course-Syllabus-master/week_2/2.3 More Command Line Tools.md
# 129772  ./Python/Python Bridge/Course-Syllabus-master/week_2/2.7.1_Mutabilty_Example.pptx
# 48790   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.10 Source Control.pptx
# 1700    ./Python/Python Bridge/Course-Syllabus-master/week_2/Mutability_notes.ipynb
# 3566    ./Python/Python Bridge/Course-Syllabus-master/week_2/2.13 Git Vocabulary.md
# 54103   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.14 Installing Git - Reading Card.md.pdf
# 30962   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.11 Source Control Reading Card.md.pdf
# 4449    ./Python/Python Bridge/Course-Syllabus-master/week_2/discussion.md
# 50143   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.6 Lists_and_Mutability.pptx
# 5830    ./Python/Python Bridge/Course-Syllabus-master/week_2/2.7 Mutability.py
# 136677  ./Python/Python Bridge/Course-Syllabus-master/week_2/2.3 More Command Line Tools.md.pdf
# 156     ./Python/Python Bridge/Course-Syllabus-master/week_2/name_game.py
# 9913    ./Python/Python Bridge/Course-Syllabus-master/week_2/.ipynb_checkpoints/2.5 - Lists-checkpoint.ipynb
# 4916    ./Python/Python Bridge/Course-Syllabus-master/week_2/.ipynb_checkpoints/2.9 - Ranges-checkpoint.ipynb
# 18579   ./Python/Python Bridge/Course-Syllabus-master/week_2/.ipynb_checkpoints/2.4 - Sequences-checkpoint.ipynb
# 1700    ./Python/Python Bridge/Course-Syllabus-master/week_2/.ipynb_checkpoints/Mutability_notes-checkpoint.ipynb
# 6324    ./Python/Python Bridge/Course-Syllabus-master/week_2/.ipynb_checkpoints/2.8 - Tuples-checkpoint.ipynb
# 41656   ./Python/Python Bridge/Course-Syllabus-master/week_2/.ipynb_checkpoints
# 18579   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.4 - Sequences.ipynb
# 129903  ./Python/Python Bridge/Course-Syllabus-master/week_2/2.15 Starting Out With Git.md.pdf
# 6348    ./Python/Python Bridge/Course-Syllabus-master/week_2/2.15 Starting Out With Git.md
# 10029   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.5 - Lists.ipynb
# 105146  ./Python/Python Bridge/Course-Syllabus-master/week_2/2.13 Git Vocabulary.md.pdf
# 400     ./Python/Python Bridge/Course-Syllabus-master/week_2/2.14 Installing Git - Reading Card.md
# 6324    ./Python/Python Bridge/Course-Syllabus-master/week_2/2.8 - Tuples.ipynb
# 329     ./Python/Python Bridge/Course-Syllabus-master/week_2/2.11 Source Control Reading Card.md
# 46828   ./Python/Python Bridge/Course-Syllabus-master/week_2/2.12 Git and Distributed Source Control.pptx
# 844939  ./Python/Python Bridge/Course-Syllabus-master/week_2
# 92321   ./Python/Python Bridge/Course-Syllabus-master/week_5/5.4.1 Calling Functions.pptx
# 280     ./Python/Python Bridge/Course-Syllabus-master/week_5/namegame.py
# 9676    ./Python/Python Bridge/Course-Syllabus-master/week_5/5.4-5.6-5.8 Functions.ipynb
# 10104   ./Python/Python Bridge/Course-Syllabus-master/week_5/5.10-5.12 Namespaces.ipynb
# 6001    ./Python/Python Bridge/Course-Syllabus-master/week_5/5.14 Functions Are Objects.ipynb
# 46535   ./Python/Python Bridge/Course-Syllabus-master/week_5/5.11 Namespaces.pptx
# 3324    ./Python/Python Bridge/Course-Syllabus-master/week_5/discussion.md
# 5711    ./Python/Python Bridge/Course-Syllabus-master/week_5/study_group_wk4.ipynb
# 110908  ./Python/Python Bridge/Course-Syllabus-master/week_5/5.3 Git Branches.md.pdf
# 3647    ./Python/Python Bridge/Course-Syllabus-master/week_5/HW5.ipynb
# 41356   ./Python/Python Bridge/Course-Syllabus-master/week_5/5.4.5 Advantages of Functions.pptx
# 10067   ./Python/Python Bridge/Course-Syllabus-master/week_5/5.15 Exceptions.ipynb
# 106885  ./Python/Python Bridge/Course-Syllabus-master/week_5/5.4.3 Functions and the Call Stack.pptx
# 10104   ./Python/Python Bridge/Course-Syllabus-master/week_5/.ipynb_checkpoints/5.10-5.12 Namespaces-checkpoint.ipynb
# 9676    ./Python/Python Bridge/Course-Syllabus-master/week_5/.ipynb_checkpoints/5.4-5.6-5.8 Functions-checkpoint.ipynb
# 3378    ./Python/Python Bridge/Course-Syllabus-master/week_5/.ipynb_checkpoints/HW5-checkpoint.ipynb
# 23318   ./Python/Python Bridge/Course-Syllabus-master/week_5/.ipynb_checkpoints
# 9325    ./Python/Python Bridge/Course-Syllabus-master/week_5/5.13 Using Parameters.ipynb
# 7484    ./Python/Python Bridge/Course-Syllabus-master/week_5/5.3 Git Branches.md
# 487518  ./Python/Python Bridge/Course-Syllabus-master/week_5
# 14501   ./Python/Python Bridge/Course-Syllabus-master/week_4/Learning and hw 4.ipynb
# 5403    ./Python/Python Bridge/Course-Syllabus-master/week_4/4.9 Comprehensions.ipynb
# 18261   ./Python/Python Bridge/Course-Syllabus-master/week_4/4.8 - Arrays and Vectors.ipynb
# 3237    ./Python/Python Bridge/Course-Syllabus-master/week_4/4.7 - Algorithms - Heron_s Method.ipynb
# 7424    ./Python/Python Bridge/Course-Syllabus-master/week_4/bisect1.png
# 4125    ./Python/Python Bridge/Course-Syllabus-master/week_4/homework3feedback.png
# 4234    ./Python/Python Bridge/Course-Syllabus-master/week_4/discussion.md
# 2826    ./Python/Python Bridge/Course-Syllabus-master/week_4/study_group_week_3.md
# 7100    ./Python/Python Bridge/Course-Syllabus-master/week_4/bisect2.png
# 10784   ./Python/Python Bridge/Course-Syllabus-master/week_4/data.json
# 6245    ./Python/Python Bridge/Course-Syllabus-master/week_4/4.3 - For Loops.ipynb
# 6245    ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.3 - For Loops-checkpoint.ipynb
# 8035    ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.4 - Fancy Loop Exits-checkpoint.ipynb
# 4495    ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.6 - Algorithms - Bisection Search-checkpoint.ipynb
# 72      ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/Learning and hw 4-checkpoint.ipynb
# 4208    ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.5 - Algorithms - Exhaustive Search-checkpoint.ipynb
# 5403    ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.9 Comprehensions-checkpoint.ipynb
# 3237    ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.7 - Algorithms - Heron_s Method-checkpoint.ipynb
# 18261   ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints/4.8 - Arrays and Vectors-checkpoint.ipynb
# 50276   ./Python/Python Bridge/Course-Syllabus-master/week_4/.ipynb_checkpoints
# 8035    ./Python/Python Bridge/Course-Syllabus-master/week_4/4.4 - Fancy Loop Exits.ipynb
# 18649   ./Python/Python Bridge/Course-Syllabus-master/week_4/newton.png
# 4495    ./Python/Python Bridge/Course-Syllabus-master/week_4/4.6 - Algorithms - Bisection Search.ipynb
# 4208    ./Python/Python Bridge/Course-Syllabus-master/week_4/4.5 - Algorithms - Exhaustive Search.ipynb
# 170379  ./Python/Python Bridge/Course-Syllabus-master/week_4
# 108960  ./Python/Python Bridge/Course-Syllabus-master/week_3/3.7 Using Git and GitHub.md.pdf
# 50458   ./Python/Python Bridge/Course-Syllabus-master/week_3/3.5 GitHub Reading Card Setup.md.pdf
# 216     ./Python/Python Bridge/Course-Syllabus-master/week_3/3.5 GitHub Reading Card Setup.md
# 347694  ./Python/Python Bridge/Course-Syllabus-master/week_3/images/fork-clone-anatomy.jpg
# 414501  ./Python/Python Bridge/Course-Syllabus-master/week_3/images/playground-demo.jpg
# 391172  ./Python/Python Bridge/Course-Syllabus-master/week_3/images/pull-request-flow.jpg
# 478832  ./Python/Python Bridge/Course-Syllabus-master/week_3/images/ideal-setup.jpg
# 1632391 ./Python/Python Bridge/Course-Syllabus-master/week_3/images
# 72      ./Python/Python Bridge/Course-Syllabus-master/week_3/Untitled.ipynb
# 79404   ./Python/Python Bridge/Course-Syllabus-master/week_3/3.4 GitHub.md.pdf
# 3195    ./Python/Python Bridge/Course-Syllabus-master/week_3/Learning _notes.ipynb
# 7930    ./Python/Python Bridge/Course-Syllabus-master/week_3/discussion.md
# 76129   ./Python/Python Bridge/Course-Syllabus-master/week_3/3.6 The Course Workflow.pptx
# 6226    ./Python/Python Bridge/Course-Syllabus-master/week_3/3.7 Using Git and GitHub.md
# 1223    ./Python/Python Bridge/Course-Syllabus-master/week_3/3.4 GitHub.md
# 7155    ./Python/Python Bridge/Course-Syllabus-master/week_3/3.10 - Control and the If Statement.ipynb
# 17712   ./Python/Python Bridge/Course-Syllabus-master/week_3/3.9 - Dictionaries.ipynb
# 82811   ./Python/Python Bridge/Course-Syllabus-master/week_3/3.8 Completing Your First Exercise With Git Reading Card.md.pdf
# 1493    ./Python/Python Bridge/Course-Syllabus-master/week_3/Pascal_triangle_learning.py
# 2525    ./Python/Python Bridge/Course-Syllabus-master/week_3/3.8 Completing Your First Exercise With Git Reading Card.md
# 4806    ./Python/Python Bridge/Course-Syllabus-master/week_3/HW3.ipynb
# 4774    ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/HW3-checkpoint.ipynb
# 6182    ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/3.11 - While Loops-checkpoint.ipynb
# 9489    ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/3.3 The Jupyter Notebook-checkpoint.ipynb
# 7155    ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/3.10 - Control and the If Statement-checkpoint.ipynb
# 72      ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/Learning _notes-checkpoint.ipynb
# 17764   ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/3.9 - Dictionaries-checkpoint.ipynb
# 72      ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# 45796   ./Python/Python Bridge/Course-Syllabus-master/week_3/.ipynb_checkpoints
# 9489    ./Python/Python Bridge/Course-Syllabus-master/week_3/3.3 The Jupyter Notebook.ipynb
# 6182    ./Python/Python Bridge/Course-Syllabus-master/week_3/3.11 - While Loops.ipynb
# 2144877 ./Python/Python Bridge/Course-Syllabus-master/week_3
# 1766    ./Python/Python Bridge/Course-Syllabus-master/README.md
# 52261   ./Python/Python Bridge/Course-Syllabus-master/week_12/12.4 - pandas DataFrame.ipynb
# 41417   ./Python/Python Bridge/Course-Syllabus-master/week_12/12.1 Introducing Pandas.pptx
# 29596   ./Python/Python Bridge/Course-Syllabus-master/week_12/12.2 - pandas Overview and Core Abstractions.ipynb
# 79331   ./Python/Python Bridge/Course-Syllabus-master/week_12/12.3 - pandas Series.ipynb
# 29383   ./Python/Python Bridge/Course-Syllabus-master/week_12/.ipynb_checkpoints/12.2 - pandas Overview and Core Abstractions-checkpoint.ipynb
# 543607  ./Python/Python Bridge/Course-Syllabus-master/week_12/.ipynb_checkpoints/12.5 - Exploring Data With pandas DataFrames-checkpoint.ipynb
# 573118  ./Python/Python Bridge/Course-Syllabus-master/week_12/.ipynb_checkpoints
# 543607  ./Python/Python Bridge/Course-Syllabus-master/week_12/12.5 - Exploring Data With pandas DataFrames.ipynb
# 1319586 ./Python/Python Bridge/Course-Syllabus-master/week_12
# 214839  ./Python/Python Bridge/Course-Syllabus-master/week_13/13.2 - Advanced pandas, Continued.ipynb
# 173436  ./Python/Python Bridge/Course-Syllabus-master/week_13/.ipynb_checkpoints/13.2 - Advanced pandas, Continued-checkpoint.ipynb
# 36409   ./Python/Python Bridge/Course-Syllabus-master/week_13/.ipynb_checkpoints/13.1 - Advanced Data Analysis in pandas-checkpoint.ipynb
# 209973  ./Python/Python Bridge/Course-Syllabus-master/week_13/.ipynb_checkpoints
# 37545   ./Python/Python Bridge/Course-Syllabus-master/week_13/13.1 - Advanced Data Analysis in pandas.ipynb
# 462517  ./Python/Python Bridge/Course-Syllabus-master/week_13
# 40      ./Python/Python Bridge/Course-Syllabus-master/.gitignore
# 2360    ./Python/Python Bridge/Course-Syllabus-master/week_6/Learning.ipynb
# 20295   ./Python/Python Bridge/Course-Syllabus-master/week_6/6.6 - The Python Standard Library.ipynb
# 8081    ./Python/Python Bridge/Course-Syllabus-master/week_6/6.7 - Frequency Counter.ipynb
# 45498   ./Python/Python Bridge/Course-Syllabus-master/week_6/6.3 - Modules and Packages.pptx
# 716     ./Python/Python Bridge/Course-Syllabus-master/week_6/__pycache__/weatherman.cpython-35.pyc
# 428     ./Python/Python Bridge/Course-Syllabus-master/week_6/__pycache__/report.cpython-35.pyc
# 1272    ./Python/Python Bridge/Course-Syllabus-master/week_6/__pycache__
# 93      ./Python/Python Bridge/Course-Syllabus-master/week_6/test.py
# 274     ./Python/Python Bridge/Course-Syllabus-master/week_6/wc.txt
# 559     ./Python/Python Bridge/Course-Syllabus-master/week_6/weatherman.py
# 17264   ./Python/Python Bridge/Course-Syllabus-master/week_6/6.5 - Packages.ipynb
# 13395   ./Python/Python Bridge/Course-Syllabus-master/week_6/6.4 - Modules and the Import Statement.ipynb
# 18842   ./Python/Python Bridge/Course-Syllabus-master/week_6/.ipynb_checkpoints/6.6 - The Python Standard Library-checkpoint.ipynb
# 17264   ./Python/Python Bridge/Course-Syllabus-master/week_6/.ipynb_checkpoints/6.5 - Packages-checkpoint.ipynb
# 3358    ./Python/Python Bridge/Course-Syllabus-master/week_6/.ipynb_checkpoints/6.7 - Frequency Counter-checkpoint.ipynb
# 2360    ./Python/Python Bridge/Course-Syllabus-master/week_6/.ipynb_checkpoints/Learning-checkpoint.ipynb
# 11325   ./Python/Python Bridge/Course-Syllabus-master/week_6/.ipynb_checkpoints/6.4 - Modules and the Import Statement-checkpoint.ipynb
# 53373   ./Python/Python Bridge/Course-Syllabus-master/week_6/.ipynb_checkpoints
# 1977    ./Python/Python Bridge/Course-Syllabus-master/week_6/weather/weekly.py
# 0       ./Python/Python Bridge/Course-Syllabus-master/week_6/weather/__init__.py
# 832     ./Python/Python Bridge/Course-Syllabus-master/week_6/weather/daily.py
# 2969    ./Python/Python Bridge/Course-Syllabus-master/week_6/weather
# 141     ./Python/Python Bridge/Course-Syllabus-master/week_6/helloworld.py
# 241     ./Python/Python Bridge/Course-Syllabus-master/week_6/showarguments.py
# 1962    ./Python/Python Bridge/Course-Syllabus-master/week_6/output.htm
# 191     ./Python/Python Bridge/Course-Syllabus-master/week_6/report.py
# 168544  ./Python/Python Bridge/Course-Syllabus-master/week_6
# 2527    ./Python/Python Bridge/Course-Syllabus-master/week_1/1.15 - First Module.ipynb
# 1142    ./Python/Python Bridge/Course-Syllabus-master/week_1/1.6.1 Creating a Course Working Directory.ipynb
# 8367    ./Python/Python Bridge/Course-Syllabus-master/week_1/1.6 The Command Line.md
# 4735    ./Python/Python Bridge/Course-Syllabus-master/week_1/1.7 Starting Python.ipynb
# 130008  ./Python/Python Bridge/Course-Syllabus-master/week_1/1.13 Variables.pptx
# 719610  ./Python/Python Bridge/Course-Syllabus-master/week_1/1.3 - 1.5 Intro to Python.pptx
# 103134  ./Python/Python Bridge/Course-Syllabus-master/week_1/1.5.1 Installing Bash for Windows Users.md.pdf
# 223268  ./Python/Python Bridge/Course-Syllabus-master/week_1/1.8 Objects.pptx
# 204     ./Python/Python Bridge/Course-Syllabus-master/week_1/longest_word.py
# 2527    ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints/1.15 - First Module-checkpoint.ipynb
# 10629   ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints/1.11 - Numbers-checkpoint.ipynb
# 18482   ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints/1.14 - Strings-checkpoint.ipynb
# 10472   ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints/1.12 - Variables-checkpoint.ipynb
# 4735    ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints/1.7 Starting Python-checkpoint.ipynb
# 12466   ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints/1.9 - Objects and Types-checkpoint.ipynb
# 59567   ./Python/Python Bridge/Course-Syllabus-master/week_1/.ipynb_checkpoints
# 10472   ./Python/Python Bridge/Course-Syllabus-master/week_1/1.12 - Variables.ipynb
# 12466   ./Python/Python Bridge/Course-Syllabus-master/week_1/1.9 - Objects and Types.ipynb
# 2199    ./Python/Python Bridge/Course-Syllabus-master/week_1/1.5.1 Installing Bash for Windows Users.md
# 18482   ./Python/Python Bridge/Course-Syllabus-master/week_1/1.14 - Strings.ipynb
# 111890  ./Python/Python Bridge/Course-Syllabus-master/week_1/1.6 The Command Line.md.pdf
# 10629   ./Python/Python Bridge/Course-Syllabus-master/week_1/1.11 - Numbers.ipynb
# 47857   ./Python/Python Bridge/Course-Syllabus-master/week_1/1.10 Representing Numbers.pptx
# 1467165 ./Python/Python Bridge/Course-Syllabus-master/week_1
# 47520   ./Python/Python Bridge/Course-Syllabus-master/week_8/8.6 Object Oriented Programming.pptx
# 10470   ./Python/Python Bridge/Course-Syllabus-master/week_8/8.5 - More Class Inheritance.ipynb
# 10849   ./Python/Python Bridge/Course-Syllabus-master/week_8/8.4 - Class Inheritance.ipynb
# 45072   ./Python/Python Bridge/Course-Syllabus-master/week_8/.ipynb_checkpoints/8.7 - Using Polymorphism-checkpoint.ipynb
# 10470   ./Python/Python Bridge/Course-Syllabus-master/week_8/.ipynb_checkpoints/8.5 - More Class Inheritance-checkpoint.ipynb
# 10849   ./Python/Python Bridge/Course-Syllabus-master/week_8/.ipynb_checkpoints/8.4 - Class Inheritance-checkpoint.ipynb
# 66551   ./Python/Python Bridge/Course-Syllabus-master/week_8/.ipynb_checkpoints
# 46163   ./Python/Python Bridge/Course-Syllabus-master/week_8/8.3 Inheritance.pptx
# 4992    ./Python/Python Bridge/Course-Syllabus-master/week_8/8.8 - Multiple Inheritance.ipynb
# 17317   ./Python/Python Bridge/Course-Syllabus-master/week_8/8.9 - Magic Methods.ipynb
# 45072   ./Python/Python Bridge/Course-Syllabus-master/week_8/8.7 - Using Polymorphism.ipynb
# 249254  ./Python/Python Bridge/Course-Syllabus-master/week_8
# 9022    ./Python/Python Bridge/Course-Syllabus-master/week_9/9.4 - Unicode Strings.ipynb
# 207     ./Python/Python Bridge/Course-Syllabus-master/week_9/grades.json
# 49596   ./Python/Python Bridge/Course-Syllabus-master/week_9/cal-image.png
# 100184  ./Python/Python Bridge/Course-Syllabus-master/week_9/9.3 - Encoding Text.pptx
# 339     ./Python/Python Bridge/Course-Syllabus-master/week_9/grades.xml
# 16251   ./Python/Python Bridge/Course-Syllabus-master/week_9/9.10 - Structured Text Files.ipynb
# 13675   ./Python/Python Bridge/Course-Syllabus-master/week_9/9.8 - Binary Data.ipynb
# 24209   ./Python/Python Bridge/Course-Syllabus-master/week_9/9.7 - Regular Expressions.ipynb
# 16914   ./Python/Python Bridge/Course-Syllabus-master/week_9/9.6 - Formatting.ipynb
# 149     ./Python/Python Bridge/Course-Syllabus-master/week_9/grades_python.json
# 18963   ./Python/Python Bridge/Course-Syllabus-master/week_9/9.9 - File Input and Output.ipynb
# 16251   ./Python/Python Bridge/Course-Syllabus-master/week_9/.ipynb_checkpoints/9.10 - Structured Text Files-checkpoint.ipynb
# 19043   ./Python/Python Bridge/Course-Syllabus-master/week_9/.ipynb_checkpoints/9.9 - File Input and Output-checkpoint.ipynb
# 24209   ./Python/Python Bridge/Course-Syllabus-master/week_9/.ipynb_checkpoints/9.7 - Regular Expressions-checkpoint.ipynb
# 59663   ./Python/Python Bridge/Course-Syllabus-master/week_9/.ipynb_checkpoints
# 255     ./Python/Python Bridge/Course-Syllabus-master/week_9/binary
# 17627   ./Python/Python Bridge/Course-Syllabus-master/week_9/9.5 - Encoding.ipynb
# 50      ./Python/Python Bridge/Course-Syllabus-master/week_9/grades.csv
# 63      ./Python/Python Bridge/Course-Syllabus-master/week_9/shakespeare.txt
# 327743  ./Python/Python Bridge/Course-Syllabus-master/week_9
# 19456   ./Python/Python Bridge/Course-Syllabus-master/week_7/Galton_Box.png
# 17790   ./Python/Python Bridge/Course-Syllabus-master/week_7/7.8 - Controlling Access to Attributes.ipynb
# 69902   ./Python/Python Bridge/Course-Syllabus-master/week_7/7.3 Classes_Introduction.pptx
# 6534    ./Python/Python Bridge/Course-Syllabus-master/week_7/7.5 - Using the Class Definition.ipynb
# 7712    ./Python/Python Bridge/Course-Syllabus-master/week_7/7.7 - Initializing a Class.ipynb
# 17412   ./Python/Python Bridge/Course-Syllabus-master/week_7/7.9 - Class Odds and Ends.ipynb
# 6215    ./Python/Python Bridge/Course-Syllabus-master/week_7/.ipynb_checkpoints/7.5 - Using the Class Definition-checkpoint.ipynb
# 17790   ./Python/Python Bridge/Course-Syllabus-master/week_7/.ipynb_checkpoints/7.8 - Controlling Access to Attributes-checkpoint.ipynb
# 11262   ./Python/Python Bridge/Course-Syllabus-master/week_7/.ipynb_checkpoints/7.4 - Classes and Attributes-checkpoint.ipynb
# 7712    ./Python/Python Bridge/Course-Syllabus-master/week_7/.ipynb_checkpoints/7.7 - Initializing a Class-checkpoint.ipynb
# 43171   ./Python/Python Bridge/Course-Syllabus-master/week_7/.ipynb_checkpoints
# 55984   ./Python/Python Bridge/Course-Syllabus-master/week_7/7.6 Binding Methods.pptx
# 11576   ./Python/Python Bridge/Course-Syllabus-master/week_7/7.4 - Classes and Attributes.ipynb
# 249889  ./Python/Python Bridge/Course-Syllabus-master/week_7
# 5113    ./Python/Python Bridge/Course-Syllabus-master/student_discovered_resources.md
# 137     ./Python/Python Bridge/Course-Syllabus-master/.git/config
# 64      ./Python/Python Bridge/Course-Syllabus-master/.git/objects/pack
# 64      ./Python/Python Bridge/Course-Syllabus-master/.git/objects/info
# 256     ./Python/Python Bridge/Course-Syllabus-master/.git/objects
# 23      ./Python/Python Bridge/Course-Syllabus-master/.git/HEAD
# 250     ./Python/Python Bridge/Course-Syllabus-master/.git/info/exclude
# 346     ./Python/Python Bridge/Course-Syllabus-master/.git/info
# 73      ./Python/Python Bridge/Course-Syllabus-master/.git/description
# 896     ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/commit-msg.sample
# 4951    ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/pre-rebase.sample
# 1642    ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/pre-commit.sample
# 452     ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/applypatch-msg.sample
# 1239    ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/prepare-commit-msg.sample
# 189     ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/post-update.sample
# 398     ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/pre-applypatch.sample
# 1348    ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/pre-push.sample
# 3611    ./Python/Python Bridge/Course-Syllabus-master/.git/hooks/update.sample
# 15078   ./Python/Python Bridge/Course-Syllabus-master/.git/hooks
# 64      ./Python/Python Bridge/Course-Syllabus-master/.git/refs/heads
# 64      ./Python/Python Bridge/Course-Syllabus-master/.git/refs/tags
# 256     ./Python/Python Bridge/Course-Syllabus-master/.git/refs
# 64      ./Python/Python Bridge/Course-Syllabus-master/.git/branches
# 0       ./Python/Python Bridge/Course-Syllabus-master/.git/FETCH_HEAD
# 16585   ./Python/Python Bridge/Course-Syllabus-master/.git
# 3099    ./Python/Python Bridge/Course-Syllabus-master/data/date_fixed_running_data.csv
# 24736   ./Python/Python Bridge/Course-Syllabus-master/data/date_fixed_running_data_with_time.html
# 1482    ./Python/Python Bridge/Course-Syllabus-master/data/raw_running_data.csv
# 5320    ./Python/Python Bridge/Course-Syllabus-master/data/date_fixed_running_data_with_time.csv
# 34752262 ./Python/Python Bridge/Course-Syllabus-master/data/airline.csv
# 12754   ./Python/Python Bridge/Course-Syllabus-master/data/date_fixed_running_data_with_time.json
# 3413384 ./Python/Python Bridge/Course-Syllabus-master/data/census.csv
# 41167509 ./Python/Python Bridge/Course-Syllabus-master/data/june_airplane_data.csv
# 79380866 ./Python/Python Bridge/Course-Syllabus-master/data
# 87838745 ./Python/Python Bridge/Course-Syllabus-master
# 8780    ./Python/Python Bridge/course_materials/week_11/minutes_per_mile_histogram.png
# 1534    ./Python/Python Bridge/course_materials/week_11/Untitled1.ipynb
# 9316    ./Python/Python Bridge/course_materials/week_11/mins per mile hist.png
# 1255    ./Python/Python Bridge/course_materials/week_11/Untitled.ipynb
# 592459  ./Python/Python Bridge/course_materials/week_11/11.5 Exploring Data With pandas DataFrames.ipynb
# 41417   ./Python/Python Bridge/course_materials/week_11/11.1 Introducing Pandas.pptx
# 9642    ./Python/Python Bridge/course_materials/week_11/11.6 Assignment.ipynb
# 79162   ./Python/Python Bridge/course_materials/week_11/11.3 - pandas Series.ipynb
# 52087   ./Python/Python Bridge/course_materials/week_11/11.4 - pandas DataFrame.ipynb
# 29541   ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints/11.2 - pandas Overview and Core Abstractions-checkpoint.ipynb
# 72      ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints/Untitled1-checkpoint.ipynb
# 72      ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# 541034  ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints/11.5 Exploring Data With pandas DataFrames-checkpoint.ipynb
# 52087   ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints/11.4 - pandas DataFrame-checkpoint.ipynb
# 79670   ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints/11.3 - pandas Series-checkpoint.ipynb
# 702732  ./Python/Python Bridge/course_materials/week_11/.ipynb_checkpoints
# 29364   ./Python/Python Bridge/course_materials/week_11/11.2 - pandas Overview and Core Abstractions.ipynb
# 1528164 ./Python/Python Bridge/course_materials/week_11
# 28918   ./Python/Python Bridge/course_materials/week_10/10.4 - NumPy Vectorization and Multi-Dimensional Arrays.ipynb
# 28812   ./Python/Python Bridge/course_materials/week_10/10.2 - Functional Programming and Data Manipulation.ipynb
# 221613  ./Python/Python Bridge/course_materials/week_10/10.1 - The PyData Ecosystem.pptx
# 31196   ./Python/Python Bridge/course_materials/week_10/10.3 -  NumPy Basics of Boolean Selection and Types.ipynb
# 55638   ./Python/Python Bridge/course_materials/week_10/10.6 - Assignment.ipynb
# 28865   ./Python/Python Bridge/course_materials/week_10/10.5 - Query, Slicing, Combining Arrays.ipynb
# 28524   ./Python/Python Bridge/course_materials/week_10/.ipynb_checkpoints/10.5 - Query, Slicing, Combining Arrays-checkpoint.ipynb
# 29253   ./Python/Python Bridge/course_materials/week_10/.ipynb_checkpoints/10.4 - NumPy Vectorization and Multi-Dimensional Arrays-checkpoint.ipynb
# 55638   ./Python/Python Bridge/course_materials/week_10/.ipynb_checkpoints/10.6 - Assignment-checkpoint.ipynb
# 29493   ./Python/Python Bridge/course_materials/week_10/.ipynb_checkpoints/10.2 - Functional Programming and Data Manipulation-checkpoint.ipynb
# 32008   ./Python/Python Bridge/course_materials/week_10/.ipynb_checkpoints/10.3 -  NumPy Basics of Boolean Selection and Types-checkpoint.ipynb
# 175140  ./Python/Python Bridge/course_materials/week_10/.ipynb_checkpoints
# 570470  ./Python/Python Bridge/course_materials/week_10
# 4956    ./Python/Python Bridge/course_materials/week_2/2.9 - Ranges.ipynb
# 7874    ./Python/Python Bridge/course_materials/week_2/2.3 More Command Line Tools.md
# 129772  ./Python/Python Bridge/course_materials/week_2/2.7.1_Mutabilty_Example.pptx
# 48790   ./Python/Python Bridge/course_materials/week_2/2.10 Source Control.pptx
# 3663    ./Python/Python Bridge/course_materials/week_2/2.13 Git Vocabulary.md
# 50143   ./Python/Python Bridge/course_materials/week_2/2.6 Lists_and_Mutability.pptx
# 5834    ./Python/Python Bridge/course_materials/week_2/2.7 Mutability.py
# 9005    ./Python/Python Bridge/course_materials/week_2/Old version of 2.5 More about Mutability.ipynb
# 156     ./Python/Python Bridge/course_materials/week_2/name_game.py
# 64      ./Python/Python Bridge/course_materials/week_2/.ipynb_checkpoints
# 18579   ./Python/Python Bridge/course_materials/week_2/2.4 - Sequences.ipynb
# 6404    ./Python/Python Bridge/course_materials/week_2/2.15 Starting Out With Git.md
# 9913    ./Python/Python Bridge/course_materials/week_2/2.5 - Lists.ipynb
# 400     ./Python/Python Bridge/course_materials/week_2/2.14 Installing Git - Reading Card.md
# 6324    ./Python/Python Bridge/course_materials/week_2/2.8 - Tuples.ipynb
# 329     ./Python/Python Bridge/course_materials/week_2/2.11 Source Control Reading Card.md
# 46828   ./Python/Python Bridge/course_materials/week_2/2.12 Git and Distributed Source Control.pptx
# 349642  ./Python/Python Bridge/course_materials/week_2
# 19108   ./Python/Python Bridge/course_materials/week_5/5.6 - The Python Standard Library.ipynb
# 2264    ./Python/Python Bridge/course_materials/week_5/Week 5 Assignment.ipynb
# 17233   ./Python/Python Bridge/course_materials/week_5/5.5 - Packages.ipynb
# 45498   ./Python/Python Bridge/course_materials/week_5/5.3 - Modules and Packages.pptx
# 520     ./Python/Python Bridge/course_materials/week_5/weatherman.py
# 3693    ./Python/Python Bridge/course_materials/week_5/.ipynb_checkpoints/5.7 - Frequency Counter-checkpoint.ipynb
# 3789    ./Python/Python Bridge/course_materials/week_5/.ipynb_checkpoints
# 1938    ./Python/Python Bridge/course_materials/week_5/weather/weekly.py
# 0       ./Python/Python Bridge/course_materials/week_5/weather/__init__.py
# 793     ./Python/Python Bridge/course_materials/week_5/weather/daily.py
# 2891    ./Python/Python Bridge/course_materials/week_5/weather
# 141     ./Python/Python Bridge/course_materials/week_5/helloworld.py
# 3693    ./Python/Python Bridge/course_materials/week_5/5.7 - Frequency Counter.ipynb
# 13519   ./Python/Python Bridge/course_materials/week_5/5.4 - Modules and the Import Statement.ipynb
# 241     ./Python/Python Bridge/course_materials/week_5/showarguments.py
# 109313  ./Python/Python Bridge/course_materials/week_5
# 280     ./Python/Python Bridge/course_materials/week_4/namegame.py
# 9313    ./Python/Python Bridge/course_materials/week_4/4.13 Using Parameters.ipynb
# 41356   ./Python/Python Bridge/course_materials/week_4/4.4.5 Advantages of Functions.pptx
# 5987    ./Python/Python Bridge/course_materials/week_4/4.14 Functions Are Objects.ipynb
# 10100   ./Python/Python Bridge/course_materials/week_4/4.10-4.12 Namespaces.ipynb
# 9499    ./Python/Python Bridge/course_materials/week_4/4.4-4.6-4.8 Functions.ipynb
# 92321   ./Python/Python Bridge/course_materials/week_4/4.4.1 Calling Functions.pptx
# 1956    ./Python/Python Bridge/course_materials/week_4/4.14.1 Functions Are Objects Exercises..ipynb
# 46535   ./Python/Python Bridge/course_materials/week_4/4.11 Namespaces.pptx
# 2237    ./Python/Python Bridge/course_materials/week_4/4.15.1 Exception Exercises.ipynb
# 1806    ./Python/Python Bridge/course_materials/week_4/4.4.4 Function Exercises.ipynb
# 106885  ./Python/Python Bridge/course_materials/week_4/4.4.3 Functions and the Call Stack.pptx
# 10007   ./Python/Python Bridge/course_materials/week_4/4.15 Exceptions.ipynb
# 64      ./Python/Python Bridge/course_materials/week_4/.ipynb_checkpoints
# 1450    ./Python/Python Bridge/course_materials/week_4/4.12.1 Namespace Exercises.ipynb
# 8014    ./Python/Python Bridge/course_materials/week_4/4.3 Git Branches.md
# 348386  ./Python/Python Bridge/course_materials/week_4
# 5758    ./Python/Python Bridge/course_materials/week_3/3.17.1 Comprehension Exercises.ipynb
# 216     ./Python/Python Bridge/course_materials/week_3/3.5 GitHub Reading Card Setup.md
# 3187    ./Python/Python Bridge/course_materials/week_3/3.12.1 - Loop Exercises.ipynb
# 5603    ./Python/Python Bridge/course_materials/week_3/3.17 Comprehensions.ipynb
# 1980    ./Python/Python Bridge/course_materials/week_3/3.16.1 Algorithms Exercises.ipynb
# 7424    ./Python/Python Bridge/course_materials/week_3/bisect1.png
# 8035    ./Python/Python Bridge/course_materials/week_3/3.13 - Fancy Loop Exits.ipynb
# 76129   ./Python/Python Bridge/course_materials/week_3/3.6 The Course Workflow.pptx
# 7100    ./Python/Python Bridge/course_materials/week_3/bisect2.png
# 1310    ./Python/Python Bridge/course_materials/week_3/3.11.1 - If Statement Exercises.ipynb
# 6264    ./Python/Python Bridge/course_materials/week_3/3.7 Using Git and GitHub.md
# 3237    ./Python/Python Bridge/course_materials/week_3/3.16 - Algorithms - Heron_s Method.ipynb
# 9732    ./Python/Python Bridge/course_materials/week_3/3.12 - Loops.ipynb
# 1597    ./Python/Python Bridge/course_materials/week_3/3.4 GitHub.md
# 17542   ./Python/Python Bridge/course_materials/week_3/3.9 - Dictionaries.ipynb
# 17565   ./Python/Python Bridge/course_materials/week_3/3.10 - Arrays and Vectors.ipynb
# 7151    ./Python/Python Bridge/course_materials/week_3/3.11 - Control and the If Statement.ipynb
# 2533    ./Python/Python Bridge/course_materials/week_3/3.8 Completing Your First Exercise With Git Reading Card.md
# 2930    ./Python/Python Bridge/course_materials/week_3/.ipynb_checkpoints/3.17.1 Comprehension Exercises-checkpoint.ipynb
# 5603    ./Python/Python Bridge/course_materials/week_3/.ipynb_checkpoints/3.17 Comprehensions-checkpoint.ipynb
# 4758    ./Python/Python Bridge/course_materials/week_3/.ipynb_checkpoints/3.15 - Algorithms - Bisection Search-checkpoint.ipynb
# 2099    ./Python/Python Bridge/course_materials/week_3/.ipynb_checkpoints/3.15.1 Bisection Search Exercises-checkpoint.ipynb
# 15582   ./Python/Python Bridge/course_materials/week_3/.ipynb_checkpoints
# 2099    ./Python/Python Bridge/course_materials/week_3/3.15.1 Bisection Search Exercises.ipynb
# 9244    ./Python/Python Bridge/course_materials/week_3/3.3 The Jupyter Notebook.ipynb
# 4208    ./Python/Python Bridge/course_materials/week_3/3.14 - Algorithms - Exhaustive Search.ipynb
# 1677    ./Python/Python Bridge/course_materials/week_3/3.8.1 GitHub_Exercise.ipynb
# 18649   ./Python/Python Bridge/course_materials/week_3/newton.png
# 4758    ./Python/Python Bridge/course_materials/week_3/3.15 - Algorithms - Bisection Search.ipynb
# 239444  ./Python/Python Bridge/course_materials/week_3
# 232     ./Python/Python Bridge/course_materials/README.md
# 173587  ./Python/Python Bridge/course_materials/week_12/12.2 Advanced pandas, Continued.ipynb
# 36433   ./Python/Python Bridge/course_materials/week_12/12.1 Advanced Data Analysis in pandas.ipynb
# 173436  ./Python/Python Bridge/course_materials/week_12/.ipynb_checkpoints/12.2 Advanced pandas, Continued-checkpoint.ipynb
# 36433   ./Python/Python Bridge/course_materials/week_12/.ipynb_checkpoints/12.1 Advanced Data Analysis in pandas-checkpoint.ipynb
# 209997  ./Python/Python Bridge/course_materials/week_12/.ipynb_checkpoints
# 18522   ./Python/Python Bridge/course_materials/week_12/12.3 Assignment.ipynb
# 438731  ./Python/Python Bridge/course_materials/week_12
# 17790   ./Python/Python Bridge/course_materials/week_6/6.8 - Controlling Access to Attributes.ipynb
# 69902   ./Python/Python Bridge/course_materials/week_6/6.3 Classes_Introduction.pptx
# 6215    ./Python/Python Bridge/course_materials/week_6/6.5 - Using the Class Definition.ipynb
# 11262   ./Python/Python Bridge/course_materials/week_6/6.4 - Classes and Attributes.ipynb
# 55984   ./Python/Python Bridge/course_materials/week_6/6.6 Binding Methods.pptx
# 17558   ./Python/Python Bridge/course_materials/week_6/.ipynb_checkpoints/6.9 - Class Odds and Ends-checkpoint.ipynb
# 17654   ./Python/Python Bridge/course_materials/week_6/.ipynb_checkpoints
# 7712    ./Python/Python Bridge/course_materials/week_6/6.7 - Initializing a Class.ipynb
# 17558   ./Python/Python Bridge/course_materials/week_6/6.9 - Class Odds and Ends.ipynb
# 30940   ./Python/Python Bridge/course_materials/week_6/6.4.1 - Data Attribute Exercises.ipynb
# 235369  ./Python/Python Bridge/course_materials/week_6
# 2527    ./Python/Python Bridge/course_materials/week_1/1.15 - First Module.ipynb
# 1142    ./Python/Python Bridge/course_materials/week_1/1.6.1 Creating a Course Working Directory.ipynb
# 8720    ./Python/Python Bridge/course_materials/week_1/1.8 The Command Line.md
# 8846    ./Python/Python Bridge/course_materials/week_1/1.6 The Command Line.md
# 4735    ./Python/Python Bridge/course_materials/week_1/1.7 Starting Python.ipynb
# 2084    ./Python/Python Bridge/course_materials/week_1/Week_1_Assignment.ipynb
# 130008  ./Python/Python Bridge/course_materials/week_1/1.13 Variables.pptx
# 719610  ./Python/Python Bridge/course_materials/week_1/1.3 - 1.5 Intro to Python.pptx
# 223268  ./Python/Python Bridge/course_materials/week_1/1.8 Objects.pptx
# 204     ./Python/Python Bridge/course_materials/week_1/longest_word.py
# 12400   ./Python/Python Bridge/course_materials/week_1/.ipynb_checkpoints/1.9 - Objects and Types-checkpoint.ipynb
# 12496   ./Python/Python Bridge/course_materials/week_1/.ipynb_checkpoints
# 10472   ./Python/Python Bridge/course_materials/week_1/1.12 - Variables.ipynb
# 12400   ./Python/Python Bridge/course_materials/week_1/1.9 - Objects and Types.ipynb
# 58      ./Python/Python Bridge/course_materials/week_1/1.5.1 Installing Bash for Windows Users.md
# 18482   ./Python/Python Bridge/course_materials/week_1/1.14 - Strings.ipynb
# 10629   ./Python/Python Bridge/course_materials/week_1/1.11 - Numbers.ipynb
# 47857   ./Python/Python Bridge/course_materials/week_1/1.10 Representing Numbers.pptx
# 1214146 ./Python/Python Bridge/course_materials/week_1
# 207     ./Python/Python Bridge/course_materials/week_8/grades.json
# 24118   ./Python/Python Bridge/course_materials/week_8/8.7 - Regular Expressions.ipynb
# 49596   ./Python/Python Bridge/course_materials/week_8/cal-image.png
# 17608   ./Python/Python Bridge/course_materials/week_8/8.5 - Encoding.ipynb
# 339     ./Python/Python Bridge/course_materials/week_8/grades.xml
# ...
# 218922  ./Python/python_data_analysis/datasets/babynames/yob1975.txt
# 132602  ./Python/python_data_analysis/datasets/babynames/yob1949.txt
# 132465  ./Python/python_data_analysis/datasets/babynames/yob1948.txt
# 210367  ./Python/python_data_analysis/datasets/babynames/yob1974.txt
# 154001  ./Python/python_data_analysis/datasets/babynames/yob1960.txt
# 224880  ./Python/python_data_analysis/datasets/babynames/yob1976.txt
# 157847  ./Python/python_data_analysis/datasets/babynames/yob1962.txt
# 309368  ./Python/python_data_analysis/datasets/babynames/yob1989.txt
# 290744  ./Python/python_data_analysis/datasets/babynames/yob1988.txt
# 158855  ./Python/python_data_analysis/datasets/babynames/yob1963.txt
# 234872  ./Python/python_data_analysis/datasets/babynames/yob1977.txt
# 137658  ./Python/python_data_analysis/datasets/babynames/yob1952.txt
# 125383  ./Python/python_data_analysis/datasets/babynames/yob1946.txt
# 327121  ./Python/python_data_analysis/datasets/babynames/yob1991.txt
# 260173  ./Python/python_data_analysis/datasets/babynames/yob1985.txt
# 252513  ./Python/python_data_analysis/datasets/babynames/yob1984.txt
# 321960  ./Python/python_data_analysis/datasets/babynames/yob1990.txt
# 133917  ./Python/python_data_analysis/datasets/babynames/yob1947.txt
# 140015  ./Python/python_data_analysis/datasets/babynames/yob1953.txt
# 246109  ./Python/python_data_analysis/datasets/babynames/yob1979.txt
# 116618  ./Python/python_data_analysis/datasets/babynames/yob1945.txt
# 135349  ./Python/python_data_analysis/datasets/babynames/yob1951.txt
# 267762  ./Python/python_data_analysis/datasets/babynames/yob1986.txt
# 331344  ./Python/python_data_analysis/datasets/babynames/yob1992.txt
# 337663  ./Python/python_data_analysis/datasets/babynames/yob1993.txt
# 278085  ./Python/python_data_analysis/datasets/babynames/yob1987.txt
# 133205  ./Python/python_data_analysis/datasets/babynames/yob1950.txt
# 118128  ./Python/python_data_analysis/datasets/babynames/yob1944.txt
# 235822  ./Python/python_data_analysis/datasets/babynames/yob1978.txt
# 115631  ./Python/python_data_analysis/datasets/babynames/yob1940.txt
# 141564  ./Python/python_data_analysis/datasets/babynames/yob1954.txt
# 167356  ./Python/python_data_analysis/datasets/babynames/yob1968.txt
# 250692  ./Python/python_data_analysis/datasets/babynames/yob1983.txt
# 349976  ./Python/python_data_analysis/datasets/babynames/yob1997.txt
# 342951  ./Python/python_data_analysis/datasets/babynames/yob1996.txt
# 254584  ./Python/python_data_analysis/datasets/babynames/yob1982.txt
# 177888  ./Python/python_data_analysis/datasets/babynames/yob1969.txt
# 143552  ./Python/python_data_analysis/datasets/babynames/yob1955.txt
# 117195  ./Python/python_data_analysis/datasets/babynames/yob1941.txt
# 149179  ./Python/python_data_analysis/datasets/babynames/yob1957.txt
# 121528  ./Python/python_data_analysis/datasets/babynames/yob1943.txt
# 338089  ./Python/python_data_analysis/datasets/babynames/yob1994.txt
# 251121  ./Python/python_data_analysis/datasets/babynames/yob1980.txt
# 251593  ./Python/python_data_analysis/datasets/babynames/yob1981.txt
# 339040  ./Python/python_data_analysis/datasets/babynames/yob1995.txt
# 121600  ./Python/python_data_analysis/datasets/babynames/yob1942.txt
# 146612  ./Python/python_data_analysis/datasets/babynames/yob1956.txt
# 446675  ./Python/python_data_analysis/datasets/babynames/yob2009.txt
# 132726  ./Python/python_data_analysis/datasets/babynames/yob1919.txt
# 119362  ./Python/python_data_analysis/datasets/babynames/yob1931.txt
# 136831  ./Python/python_data_analysis/datasets/babynames/yob1925.txt
# 29822   ./Python/python_data_analysis/datasets/babynames/yob1886.txt
# 36542   ./Python/python_data_analysis/datasets/babynames/yob1892.txt
# 35434   ./Python/python_data_analysis/datasets/babynames/yob1893.txt
# 29532   ./Python/python_data_analysis/datasets/babynames/yob1887.txt
# 139518  ./Python/python_data_analysis/datasets/babynames/yob1924.txt
# 125892  ./Python/python_data_analysis/datasets/babynames/yob1930.txt
# 133101  ./Python/python_data_analysis/datasets/babynames/yob1918.txt
# 451900  ./Python/python_data_analysis/datasets/babynames/yob2008.txt
# 134326  ./Python/python_data_analysis/datasets/babynames/yob1926.txt
# 120786  ./Python/python_data_analysis/datasets/babynames/yob1932.txt
# 33186   ./Python/python_data_analysis/datasets/babynames/yob1891.txt
# 28625   ./Python/python_data_analysis/datasets/babynames/yob1885.txt
# 5724    ./Python/python_data_analysis/datasets/babynames/NationalReadMe.pdf
# 28670   ./Python/python_data_analysis/datasets/babynames/yob1884.txt
# 33621   ./Python/python_data_analysis/datasets/babynames/yob1890.txt
# 115824  ./Python/python_data_analysis/datasets/babynames/yob1933.txt
# 133892  ./Python/python_data_analysis/datasets/babynames/yob1927.txt
# 136768  ./Python/python_data_analysis/datasets/babynames/yob1923.txt
# 115279  ./Python/python_data_analysis/datasets/babynames/yob1937.txt
# 36817   ./Python/python_data_analysis/datasets/babynames/yob1894.txt
# 24933   ./Python/python_data_analysis/datasets/babynames/yob1880.txt
# 24065   ./Python/python_data_analysis/datasets/babynames/yob1881.txt
# 38232   ./Python/python_data_analysis/datasets/babynames/yob1895.txt
# 114311  ./Python/python_data_analysis/datasets/babynames/yob1936.txt
# 138200  ./Python/python_data_analysis/datasets/babynames/yob1922.txt
# 118031  ./Python/python_data_analysis/datasets/babynames/yob1934.txt
# 137750  ./Python/python_data_analysis/datasets/babynames/yob1920.txt
# 50841   ./Python/python_data_analysis/datasets/babynames/yob1908.txt
# 26003   ./Python/python_data_analysis/datasets/babynames/yob1883.txt
# 37936   ./Python/python_data_analysis/datasets/babynames/yob1897.txt
# 38747   ./Python/python_data_analysis/datasets/babynames/yob1896.txt
# 26559   ./Python/python_data_analysis/datasets/babynames/yob1882.txt
# 53488   ./Python/python_data_analysis/datasets/babynames/yob1909.txt
# 139183  ./Python/python_data_analysis/datasets/babynames/yob1921.txt
# 116221  ./Python/python_data_analysis/datasets/babynames/yob1935.txt
# 21831475 ./Python/python_data_analysis/datasets/babynames
# 4399    ./Python/python_data_analysis/datasets/mta_perf/Performance_LIRR.xsd
# 4399    ./Python/python_data_analysis/datasets/mta_perf/Performance_NYCT.xsd
# 109040  ./Python/python_data_analysis/datasets/mta_perf/Performance_TBTA.xml
# 401235  ./Python/python_data_analysis/datasets/mta_perf/Performance_LIBUS.xml
# 529875  ./Python/python_data_analysis/datasets/mta_perf/Performance_MNR.xml
# 560081  ./Python/python_data_analysis/datasets/mta_perf/Performance_MTABUS.xml
# 782541  ./Python/python_data_analysis/datasets/mta_perf/Performance_LIRR.xml
# 3014888 ./Python/python_data_analysis/datasets/mta_perf/Performance_NYCT.xml
# 4399    ./Python/python_data_analysis/datasets/mta_perf/Performance_MTABUS.xsd
# 329     ./Python/python_data_analysis/datasets/mta_perf/parse.py
# 4399    ./Python/python_data_analysis/datasets/mta_perf/Performance_MNR.xsd
# 4399    ./Python/python_data_analysis/datasets/mta_perf/Performance_LIBUS.xsd
# 4399    ./Python/python_data_analysis/datasets/mta_perf/Performance_TBTA.xsd
# 5424863 ./Python/python_data_analysis/datasets/mta_perf
# 1598282 ./Python/python_data_analysis/datasets/bitly_usagov/example.txt
# 1598378 ./Python/python_data_analysis/datasets/bitly_usagov
# 28210   ./Python/python_data_analysis/datasets/titanic/test.csv
# 2839    ./Python/python_data_analysis/datasets/titanic/genderclassmodel.csv
# 60302   ./Python/python_data_analysis/datasets/titanic/train.csv
# 2839    ./Python/python_data_analysis/datasets/titanic/gendermodel.csv
# 94382   ./Python/python_data_analysis/datasets/titanic
# 31814355 ./Python/python_data_analysis/datasets/usda_food/database.json
# 31814451 ./Python/python_data_analysis/datasets/usda_food
# 171308  ./Python/python_data_analysis/datasets/movielens/movies.dat
# 24594131 ./Python/python_data_analysis/datasets/movielens/ratings.dat
# 5189    ./Python/python_data_analysis/datasets/movielens/README
# 134368  ./Python/python_data_analysis/datasets/movielens/users.dat
# 24905188 ./Python/python_data_analysis/datasets/movielens
# 247987127 ./Python/python_data_analysis/datasets
# 25266   ./Python/python_data_analysis/ch06.ipynb
# 33375   ./Python/python_data_analysis/ch04.ipynb
# 65436   ./Python/python_data_analysis/ch08.ipynb
# 31869   ./Python/python_data_analysis/appa.ipynb
# 2753    ./Python/python_data_analysis/README.md
# 52922   ./Python/python_data_analysis/ch11.ipynb
# 1138    ./Python/python_data_analysis/COPYING
# 12740   ./Python/python_data_analysis/ch13.ipynb
# 18      ./Python/python_data_analysis/.gitignore
# 281823  ./Python/python_data_analysis/examples/fdic_failed_bank_list.html
# 108161  ./Python/python_data_analysis/examples/stinkbug.png
# 40      ./Python/python_data_analysis/examples/test_file.csv
# 111     ./Python/python_data_analysis/examples/csv_mindex.csv
# 400602  ./Python/python_data_analysis/examples/stock_px.csv
# 91      ./Python/python_data_analysis/examples/tseries.csv
# 58      ./Python/python_data_analysis/examples/ex1.csv
# 69376   ./Python/python_data_analysis/examples/yahoo_price.pkl
# 169     ./Python/python_data_analysis/examples/ex3.csv
# 42      ./Python/python_data_analysis/examples/ex2.csv
# 626863  ./Python/python_data_analysis/examples/ex6.csv
# 101402  ./Python/python_data_analysis/examples/stock_px_2.csv
# 36      ./Python/python_data_analysis/examples/ex7.csv
# 81      ./Python/python_data_analysis/examples/example.json
# 6545    ./Python/python_data_analysis/examples/tips.csv
# 78      ./Python/python_data_analysis/examples/ex5.csv
# 218     ./Python/python_data_analysis/examples/ipython_bug.py
# 163     ./Python/python_data_analysis/examples/ex4.csv
# 5529    ./Python/python_data_analysis/examples/ex1.xlsx
# 88      ./Python/python_data_analysis/examples/out.csv
# 224     ./Python/python_data_analysis/examples/array_ex.txt
# 150105  ./Python/python_data_analysis/examples/spx.csv
# 18242   ./Python/python_data_analysis/examples/macrodata.csv
# 170     ./Python/python_data_analysis/examples/ex3.txt
# 296     ./Python/python_data_analysis/examples/segismundo.txt
# 69376   ./Python/python_data_analysis/examples/yahoo_volume.pkl
# 636635  ./Python/python_data_analysis/examples/volume.csv
# 2477452 ./Python/python_data_analysis/examples
# 20845   ./Python/python_data_analysis/.ipynb_checkpoints/ch10-checkpoint.ipynb
# 35168   ./Python/python_data_analysis/.ipynb_checkpoints/ch14-checkpoint.ipynb
# 29228   ./Python/python_data_analysis/.ipynb_checkpoints/ch11-checkpoint.ipynb
# 14469   ./Python/python_data_analysis/.ipynb_checkpoints/ch12-checkpoint.ipynb
# 56351   ./Python/python_data_analysis/.ipynb_checkpoints/ch09-checkpoint.ipynb
# 12740   ./Python/python_data_analysis/.ipynb_checkpoints/ch13-checkpoint.ipynb
# 24927   ./Python/python_data_analysis/.ipynb_checkpoints/ch07-checkpoint.ipynb
# 20919   ./Python/python_data_analysis/.ipynb_checkpoints/ch08-checkpoint.ipynb
# 214967  ./Python/python_data_analysis/.ipynb_checkpoints
# 21396   ./Python/python_data_analysis/ch12.ipynb
# 504486  ./Python/python_data_analysis/ch09.ipynb
# 319     ./Python/python_data_analysis/.git/config
# 42466975 ./Python/python_data_analysis/.git/objects/pack/pack-5dc8951a9a8922a548e5232079a00aa22711552e.pack
# 12972   ./Python/python_data_analysis/.git/objects/pack/pack-5dc8951a9a8922a548e5232079a00aa22711552e.idx
# 42480075 ./Python/python_data_analysis/.git/objects/pack
# 64      ./Python/python_data_analysis/.git/objects/info
# 42480267 ./Python/python_data_analysis/.git/objects
# 28      ./Python/python_data_analysis/.git/HEAD
# 240     ./Python/python_data_analysis/.git/info/exclude
# 336     ./Python/python_data_analysis/.git/info
# 194     ./Python/python_data_analysis/.git/logs/HEAD
# 194     ./Python/python_data_analysis/.git/logs/refs/heads/2nd-edition
# 290     ./Python/python_data_analysis/.git/logs/refs/heads
# 194     ./Python/python_data_analysis/.git/logs/refs/remotes/origin/HEAD
# 290     ./Python/python_data_analysis/.git/logs/refs/remotes/origin
# 386     ./Python/python_data_analysis/.git/logs/refs/remotes
# 804     ./Python/python_data_analysis/.git/logs/refs
# 1126    ./Python/python_data_analysis/.git/logs
# 73      ./Python/python_data_analysis/.git/description
# 896     ./Python/python_data_analysis/.git/hooks/commit-msg.sample
# 4951    ./Python/python_data_analysis/.git/hooks/pre-rebase.sample
# 1642    ./Python/python_data_analysis/.git/hooks/pre-commit.sample
# 478     ./Python/python_data_analysis/.git/hooks/applypatch-msg.sample
# 1239    ./Python/python_data_analysis/.git/hooks/prepare-commit-msg.sample
# 189     ./Python/python_data_analysis/.git/hooks/post-update.sample
# 424     ./Python/python_data_analysis/.git/hooks/pre-applypatch.sample
# 1348    ./Python/python_data_analysis/.git/hooks/pre-push.sample
# 3611    ./Python/python_data_analysis/.git/hooks/update.sample
# 15130   ./Python/python_data_analysis/.git/hooks
# 41      ./Python/python_data_analysis/.git/refs/heads/2nd-edition
# 137     ./Python/python_data_analysis/.git/refs/heads
# 64      ./Python/python_data_analysis/.git/refs/tags
# 37      ./Python/python_data_analysis/.git/refs/remotes/origin/HEAD
# 133     ./Python/python_data_analysis/.git/refs/remotes/origin
# 229     ./Python/python_data_analysis/.git/refs/remotes
# 590     ./Python/python_data_analysis/.git/refs
# 19888   ./Python/python_data_analysis/.git/index
# 64      ./Python/python_data_analysis/.git/branches
# 185     ./Python/python_data_analysis/.git/packed-refs
# 42518422 ./Python/python_data_analysis/.git
# 187591  ./Python/python_data_analysis/ch10.ipynb
# 35168   ./Python/python_data_analysis/ch14.ipynb
# 294490632 ./Python/python_data_analysis
# 937413907 ./Python
# 16047   ./data_structure_notebook.ipynb
# 56      ./Assignment2_SampleIO/scramble_example/input.txt
# 76      ./Assignment2_SampleIO/scramble_example/output.txt
# 260     ./Assignment2_SampleIO/scramble_example
# 23      ./Assignment2_SampleIO/strategy_example/input.txt
# 38      ./Assignment2_SampleIO/strategy_example/output.txt
# 189     ./Assignment2_SampleIO/strategy_example
# 577     ./Assignment2_SampleIO
# 264814664 ./return_train_2018Q4.csv
# 175018588 ./return_train_2018Q1.csv
# 0       ./test_strings.txt
# 37161   ./algorithm.ipynb
# 72      ./.ipynb_checkpoints/python_receipts-checkpoint.ipynb
# 3986    ./.ipynb_checkpoints/data_structure_notebook-checkpoint.ipynb
# 27896   ./.ipynb_checkpoints/algorithm-checkpoint.ipynb
# 32114   ./.ipynb_checkpoints
# 6023    ./1B_assignments_2016_11_10/Assignment_6/Assignment_6.ipynb
# 106243  ./1B_assignments_2016_11_10/Assignment_6/Assignment_6.pdf
# 112394  ./1B_assignments_2016_11_10/Assignment_6
# 6148    ./1B_assignments_2016_11_10/.DS_Store
# 3983    ./1B_assignments_2016_11_10/Assignment_3.rtf
# 1815    ./1B_assignments_2016_11_10/Assignment_5/Assignment_5.rtf
# 11      ./1B_assignments_2016_11_10/Assignment_5/graph_example_files/input.txt
# 1297    ./1B_assignments_2016_11_10/Assignment_5/graph_example_files/adj.txt
# 9       ./1B_assignments_2016_11_10/Assignment_5/graph_example_files/output.txt
# 1477    ./1B_assignments_2016_11_10/Assignment_5/graph_example_files
# 3420    ./1B_assignments_2016_11_10/Assignment_5
# 56      ./1B_assignments_2016_11_10/Assignment_2/scramble_example_files/input.txt
# 76      ./1B_assignments_2016_11_10/Assignment_2/scramble_example_files/output.txt
# 260     ./1B_assignments_2016_11_10/Assignment_2/scramble_example_files
# 23      ./1B_assignments_2016_11_10/Assignment_2/winning_example_files/input.txt
# 38      ./1B_assignments_2016_11_10/Assignment_2/winning_example_files/output.txt
# 189     ./1B_assignments_2016_11_10/Assignment_2/winning_example_files
# 41334   ./1B_assignments_2016_11_10/Assignment_2/Assignment_2.pdf
# 41943   ./1B_assignments_2016_11_10/Assignment_2
# 87      ./1B_assignments_2016_11_10/Assignment_4/postfix_example_files/input.txt
# 16      ./1B_assignments_2016_11_10/Assignment_4/postfix_example_files/output.txt
# 231     ./1B_assignments_2016_11_10/Assignment_4/postfix_example_files
# 2208    ./1B_assignments_2016_11_10/Assignment_4/Assignment_4.rtf
# 2567    ./1B_assignments_2016_11_10/Assignment_4
# 170711  ./1B_assignments_2016_11_10
# 41334   ./Assignment.pdf
# 673022  ./austen-sense.txt
# 139174  ./python_receipts.ipynb
# 1384645638 ./
# 1384645638

# %% [markdown]
# ## Sorting
#
# * A good way to get a lower bound on sorting time is to count the number of comparisons we have to make.
#     * Each of these takes constant time, so this works as a lower bound.
# * One way to understand sorting algorithms is that it outputs a permutation of the sequence as steps of reordering
#   * There are total of n! possible permutations, and any one of these could be the correct sorted order.
#   * If an algorithm makes only one comparison:
#     * It branches only once.
#     * It can output only one of two permutations.
#     * It can sort only a sequence with two elements.
#   * We need to figure out how many branches are needed to sort n items.
# * Fast sorting algorithm
#   * $O(log n!) = O(n log n)$
#   * popular fast algorithms: merge sort, quick sort, etc
# * Assumption: we can only use comparisons to make our algorithm branch.
# * For the general case of an unstructured space of items, O(n log n) is the important bound.

# %% [markdown]
# ### Slow Sorting Algorithms to get the concepts
#
# #### bubble sort $O(n^2)$
#
# * Steps:
#     * set sort until position in outer loop at the end of the list (outer loop)
#     * bubble up the largest item until the sort until position (inner loop)
#     * decrease sort until position by 1 as we bubble the largest item to the end of list in the inner loop
# * using a `swapped` flag to early stop if there is no swap happening in an iteration

# %%
# %time
def bubble_sort(S):
    l = len(S)
    for i in range(l-1, 0, -1):
        print(f"interation: {l-i}")
        swapped = False
        for j in range(0, i):
            if S[j] > S[j+1]:
                tmp = S[j]
                S[j] = S[j+1]
                S[j+1] = tmp
                swapped = True
        print(S)
        if not swapped: 
            break

S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
bubble_sort(S)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# interation: 1
# [4, 1, 3, 9, 20, 21, 6, 21, 14, 25]
# interation: 2
# [1, 3, 4, 9, 20, 6, 21, 14, 21, 25]
# interation: 3
# [1, 3, 4, 9, 6, 20, 14, 21, 21, 25]
# interation: 4
# [1, 3, 4, 6, 9, 14, 20, 21, 21, 25]
# interation: 5
# [1, 3, 4, 6, 9, 14, 20, 21, 21, 25]

# %% [markdown]
# #### Selection Sort $O(n^2)$
#
# * Steps:
#     * set find mininum boundry position index from the beginning of the list (outerloop), set default min_index at index 1
#     * iterate from mininum boundry until the end
#         * find the min_value index
#         * swap with mininum boundry position index from outer loop
#     * increase minium boundry index by 1

# %%
# %time
def selection_sort(S):
    for i in range(len(S)-1):
        print(f"interation: {i+1}")
        swapped = False
        min_index = i
        for j in range(i+1, len(S)):
            if S[j] < S[min_index]:
                min_index = j
        if i != min_index:
            temp = S[i]
            S[i] = S[min_index]
            S[min_index] = temp
            swapped = True
        print(S)
        if not swapped: 
            break
    return S
S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
selection_sort(S)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.96 µs
# interation: 1
# [1, 4, 21, 3, 9, 20, 25, 6, 21, 14]
# interation: 2
# [1, 3, 21, 4, 9, 20, 25, 6, 21, 14]
# interation: 3
# [1, 3, 4, 21, 9, 20, 25, 6, 21, 14]
# interation: 4
# [1, 3, 4, 6, 9, 20, 25, 21, 21, 14]
# interation: 5
# [1, 3, 4, 6, 9, 20, 25, 21, 21, 14]
# [1, 3, 4, 6, 9, 20, 25, 21, 21, 14]

# %% [markdown]
# #### insertion sort $O(n^2)$
#
# Steps:
# * outer loop start from index 1 until the end of list
#     * inner loop start from position of outer looop backwords
#     * swap the smallest to the beginning of the list
#
# Note: If it is almost sorted, it will be $O(n)$ if we use a while loop

# %%
# %time
def insertion_sort(S):
    l = len(S) 
    for i in range(1, l):
        swapped = False
        print(f"iteration: {i}")
        for j in range(i, 0, -1):
            if S[j] < S[j-1]:
                tmp = S[j]
                S[j] = S[j-1]
                S[j-1] = tmp
                swapped = True
        print(S)
        if not swapped:
            break

S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
insertion_sort(S)

print("---------------------")

# %time
def insertion_sort_while(S):
    l = len(S) 
    for i in range(1, l):
        temp = S[i]
        j = i-1
        print(f"iteration: {i}")
        while temp < S[j] and j > -1:
            S[j+1] = S[j] 
            S[j] = temp
            j -= 1
        print(S)
        
#S = [2, 1, 3, 4, 5, 6]
S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
insertion_sort_while(S)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# iteration: 1
# [4, 21, 1, 3, 9, 20, 25, 6, 21, 14]
# iteration: 2
# [1, 4, 21, 3, 9, 20, 25, 6, 21, 14]
# iteration: 3
# [1, 3, 4, 21, 9, 20, 25, 6, 21, 14]
# iteration: 4
# [1, 3, 4, 9, 21, 20, 25, 6, 21, 14]
# iteration: 5
# [1, 3, 4, 9, 20, 21, 25, 6, 21, 14]
# iteration: 6
# [1, 3, 4, 9, 20, 21, 25, 6, 21, 14]
# ---------------------
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# iteration: 1
# [4, 21, 1, 3, 9, 20, 25, 6, 21, 14]
# iteration: 2
# [1, 4, 21, 3, 9, 20, 25, 6, 21, 14]
# iteration: 3
# [1, 3, 4, 21, 9, 20, 25, 6, 21, 14]
# iteration: 4
# [1, 3, 4, 9, 21, 20, 25, 6, 21, 14]
# iteration: 5
# [1, 3, 4, 9, 20, 21, 25, 6, 21, 14]
# iteration: 6
# [1, 3, 4, 9, 20, 21, 25, 6, 21, 14]
# iteration: 7
# [1, 3, 4, 6, 9, 20, 21, 25, 21, 14]
# iteration: 8
# [1, 3, 4, 6, 9, 20, 21, 21, 25, 14]
# iteration: 9
# [1, 3, 4, 6, 9, 14, 20, 21, 21, 25]

# %% [markdown]
# ### Faster sorting algorithms
#
# #### Merge sort
#
#   * $O(n \cdot log(n))$ (n comparision, and log(n) splits)
#   * Higher cost of space since we copy to new array when sorting: Auxillary Space $O(n)$
#
#   **Key idea:**
#   * Divide and conqur
#   * Two sorted lists can be combined into one sorted list in linear time.
#   * Look at the first element in both lists, and move the smaller element to the end of the combined list.
#
#   Stepsz: (use recursion)
#   * Split a list in half
#   * base case: when len(the_list) is 1
#   * use merge() to put lists together merge() is a

# %%
# %time
def merge_sort(S):
    l = len(S)

    if l < 2:
        return S
    
    mid_index = int(len(S)/2)
    left = S[0:mid_index]
    right = S[mid_index:]

    left_list = merge_sort(left)
    right_list = merge_sort(right)

    return merge(left_list, right_list)

def merge(list1, list2):
    combined = []
    i = 0
    j = 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            combined.append(list1[i])
            i += 1
        else:
            combined.append(list2[j])
            j += 1
    while i < len(list1):
        combined.append(list1[i])
        i+=1
    while j < len(list2):
        combined.append(list2[j])
        j+=1
    return combined

def merge(left, right):
    output = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            output.append(left[i])
            i+=1
        else:
            output.append(right[j])
            j+=1
    # add remaining 1 item from either list if we have odd size
    output.extend(left[i:])
    output.extend(right[j:])
    return output

def merge_sort_space_compact(S):
    l = len(S) 
    if l < 2:
        return
    
    lo = S[0:l//2]
    hi = S[l//2:]
    
    merge_sort(lo)
    merge_sort(hi)

    del S[:]
    while len(lo) + len(hi) > 0:
        if len(hi) == 0 or (len(lo) > 0 and lo[0] < hi[0]):
            S.append(lo.pop(0))
        else:
            S.append(hi.pop(0))
    print(S)

S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
merge_sort(S)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.72 µs
# [1, 3, 4, 6, 9, 14, 20, 21, 21, 25]

# %% [markdown]
# #### Quick Sort
#   * $O(n \cdot \log(n))$
#   * **key concepts:**
#     * select a pivot from the list usually the last item
#     * put large item to an upper list, smaller item to an lower list, then concat lower, pivot and pivot list together
#     * recusrively perform the same operation to the upper and lower list
#   * It can be slow if the list is almost sorted
#   * Can use parallel operation to improve performance

# %%
# %time
# Space efficient way
def quick_sort(my_list):
    return quick_sort_helper(my_list, 0, len(my_list)-1)
    
def quick_sort_helper(my_list, left, right):
    if left < right:
        pivot_index = pivot(my_list, left, right)
        quick_sort_helper(my_list, left, pivot_index-1)
        quick_sort_helper(my_list,  pivot_index+1, right)
    return my_list
    
def swap(my_list, index1, index2):
    temp = my_list[index1]
    my_list[index1] = my_list[index2]
    my_list[index2] = temp

def pivot(my_list, pivot_index, end_index):
    swap_index = pivot_index
    for i in range(pivot_index+1, end_index+1):
        if my_list[i] < my_list[pivot_index]:
            swap_index += 1
            swap(my_list, swap_index, i)
    swap(my_list, pivot_index, swap_index)
    return swap_index

S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
quick_sort(S)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# [1, 3, 4, 6, 9, 14, 20, 21, 21, 25]

# %%
# %time
def quick_sort(S):
    l = len(S)
    if l < 2:
        return S
    
    lo = []
    up = []
    p = [S[-1]]
    for i in range(0, l-1):
        if S[i] > S[-1]:
            up.append(S[i])
        elif S[i] < S[-1]:
            lo.append(S[i])
        else:
            p.append(S[i])

    return quick_sort(lo)+p+quick_sort(up)

S = [21, 4, 1, 3, 9, 20, 25, 6, 21, 14]
quick_sort(S)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.91 µs
# [1, 3, 4, 6, 9, 14, 20, 21, 21, 25]

# %% [markdown]
# ## Sets and Map (a.k.a associated array)
#
# * Set has not orders and only unique items
# * map is a set based data structure where key is a set (unique), a key can have multiple values
# * python dictionary is a map data structure

# %%
# Some common dictionary operations

# create dictionary from 2 list (key and value)
d = dict(zip(('a', 'b', 'c', 'd', 'e'), (1, 2, 3, 4, 5)))
print(f"Created {d}")

# unpack a dictionary
# get keys
print([k for k in d])
# or
print([k for k in d.keys()])
# ket values
print([v for v in d.values()])

# swap key and value
print({v:k for k, v in d.items()})

# delete a value
del d['e']
print(f"Delete key e and its value {d}")

# Sort by key
d = dict(zip(('c', 'a', 'b', 'd'), (3, 1, 2, 4)))
print(f"Unsorted dict {d}")
print(f"Sorted by key: {sorted(d.items(), key=lambda item: item[0])}")

# Sort by value
d = dict(zip(('c', 'a', 'b', 'd'), (3, 1, 2, 4)))
print(f"Unsorted dict {d}")
print(f"Sorted by value: {sorted(d.items(), key=lambda item: item[0])}")
# Out:
# Created {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'b', 'c', 'd', 'e']
# [1, 2, 3, 4, 5]
# {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}
# Delete key e and its value {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# Unsorted dict {'c': 3, 'a': 1, 'b': 2, 'd': 4}
# Sorted by key: [('a', 1), ('b', 2), ('c', 3), ('d', 4)]
# Unsorted dict {'c': 3, 'a': 1, 'b': 2, 'd': 4}
# Sorted by value: [('a', 1), ('b', 2), ('c', 3), ('d', 4)]
